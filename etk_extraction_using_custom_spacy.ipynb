# %% [markdown]
# # Custom Spacy Rules

# %%
import json
from etk.core import Core
c = Core()

text = u"tOwN Job jOb SADFEWF Town SAEWF eewibferhi SSSSS22.111XXppppppp? sadfewf  EEWIbfERHI SADfeWF sspp, sssppp? "

field_rules = {
  "rules": [
      {
      "identifier": "an indentifier",
      "description": "a description",
      "is_active": "true/false",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["tOWN", "job"],
          "capitalization": ["title", "upper", "mixed"],
          "part_of_speech": ["noun", "pronoun"],
          "length": [],
          "prefix": "ssss",
          "suffix": "",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["lower", "upper", "mixed"],
          "part_of_speech": [],
          "length": [5, 7],
          "prefix": "SA",
          "suffix": "WF",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "EEW",
          "suffix": "RHI",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "number",
          "tokens": [],
          "length": [],
          "prefix": [],
          "suffix": [],
          "min":"",
          "max":"",
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        },
        {
          "type": "shape",
          "shapes": ["xxxx", "xxxxxx", "XXXXXdd.dddXXxxxxxxx"],
          "part_of_speech": [],
          "prefix": "ss",
          "suffix": "pp",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true"
        },
        {
          "type": "punctuation",
          "token": [",", "?"],
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true"
        },
        {
          "type": "symbol",
          "token": [],
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        }
      ]
    }
  ]
}

d = dict()
d['text'] = text

config = dict()
config['field_name'] = 'field01'

results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)

print json.dumps(results, indent=2)
# Out:
# [
#   {
#     "context": {
#       "start": 12,
#       "end": 14,
#       "rule_id": 0
#     },
#     "value": "sspp"
#   },
#   {
#     "context": {
#       "start": 5,
#       "end": 8,
#       "rule_id": 0
#     },
#     "value": "SSSSS22.111XXppppppp"
#   },
#   {
#     "context": {
#       "start": 12,
#       "end": 15,
#       "rule_id": 0
#     },
#     "value": "sspp ,"
#   },
#   {
#     "context": {
#       "start": 5,
#       "end": 9,
#       "rule_id": 0
#     },
#     "value": "SSSSS22.111XXppppppp ?"
#   }
# ]
# [
#   {
#     "context": {
#       "start": 12,
#       "end": 14,
#       "rule_id": 0
#     },
#     "value": "sspp"
#   },
#   {
#     "context": {
#       "start": 5,
#       "end": 8,
#       "rule_id": 0
#     },
#     "value": "SSSSS22.111XXppppppp"
#   },
#   {
#     "context": {
#       "start": 12,
#       "end": 15,
#       "rule_id": 0
#     },
#     "value": "sspp ,"
#   },
#   {
#     "context": {
#       "start": 5,
#       "end": 9,
#       "rule_id": 0
#     },
#     "value": "SSSSS22.111XXppppppp ?"
#   }
# ]

# %%
import json
from etk.core import Core
c = Core()

# %%
text = u" My name is Pedro"

field_rules = {
  "rules": [
      {
      "identifier": "rule_01",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["my"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["name", "names"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["is"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "false",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

d = dict()
d['text'] = text

config = dict()
config['field_name'] = 'field01'

results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)

print "hello"
#print json.dumps(results, indent=9)
results
# Out:
# [
#   {
#     "context": {
#       "start": 1,
#       "end": 4,
#       "rule_id": 0
#     },
#     "value": "is"
#   },
#   {
#     "context": {
#       "start": 1,
#       "end": 5,
#       "rule_id": 0
#     },
#     "value": "Pedro"
#   }
# ]
# hello
# [{'context': {'end': 4, 'rule_id': 0, 'start': 1}, 'value': 'is'},
#  {'context': {'end': 5, 'rule_id': 0, 'start': 1}, 'value': 'Pedro'}]
