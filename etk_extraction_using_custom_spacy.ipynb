# %% [markdown]
# # Custom Spacy Rules

# %%
sampe_rules = {
  "rules": [
      {
      "identifier": "an indentifier",
      "description": "a description",
      "is_active": "true/false",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["tOWN", "job"],
          "capitalization": ["title", "upper", "mixed"],
          "part_of_speech": ["noun", "pronoun"],
          "length": [],
          "prefix": "ssss",
          "suffix": "",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["lower", "upper", "mixed"],
          "part_of_speech": [],
          "length": [5, 7],
          "prefix": "SA",
          "suffix": "WF",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "EEW",
          "suffix": "RHI",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "number",
          "tokens": [],
          "length": [],
          "prefix": [],
          "suffix": [],
          "min":"",
          "max":"",
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        },
        {
          "type": "shape",
          "shapes": ["xxxx", "xxxxxx", "XXXXXdd.dddXXxxxxxxx"],
          "part_of_speech": [],
          "prefix": "ss",
          "suffix": "pp",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true"
        },
        {
          "type": "punctuation",
          "token": [",", "?"],
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true"
        },
        {
          "type": "symbol",
          "token": [],
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        }
      ]
    }
  ]
}

# %%
import json
from etk.core import Core
c = Core()
a=1

# %%
# text = u" My name is Pedro"

# field_rules = {
#   "rules": [
#       {
#       "identifier": "rule_01",
#       "description": "a description",
#       "is_active": "true",
#       "polarity": [],
#       "pattern": [
#         {
#           "type": "word",
#           "token": ["my"],
#           "capitalization": [],
#           "part_of_speech": [],
#           "length": [],
#           "prefix": "",
#           "suffix": "",
#           "is_followed_by_space": "",
#           "is_required": "true",
#           "is_in_output": "false",
#           "is_out_of_vocabulary": ""
#         },
#         {
#           "type": "word",
#           "token": ["name", "names"],
#           "capitalization": [],
#           "part_of_speech": [],
#           "length": [],
#           "prefix": "",
#           "suffix": "",
#           "is_followed_by_space": "",
#           "is_required": "true",
#           "is_in_output": "false",
#           "is_out_of_vocabulary": ""
#         },
#         {
#           "type": "word",
#           "token": ["is"],
#           "capitalization": [],
#           "part_of_speech": [],
#           "length": [],
#           "prefix": "",
#           "suffix": "",
#           "is_followed_by_space": "",
#           "is_required": "false",
#           "is_in_output": "false",
#           "is_out_of_vocabulary": ""
#         },
#         {
#           "type": "word",
#           "token": [],
#           "capitalization": [],
#           "part_of_speech": [],
#           "length": [],
#           "prefix": "",
#           "suffix": "",
#           "is_followed_by_space": "",
#           "is_required": "true",
#           "is_in_output": "true",
#           "is_out_of_vocabulary": ""
#         }
#       ]
#     }
#   ]
# }

# d = dict()
# d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(text, lowercase=False))

# config = dict()
# config['field_name'] = 'field01'

# results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)

# print "hello"
# #print json.dumps(results, indent=9)
# results

# %%
confirmation_rules = {
    "field_name": "price", 
    "results": [], 
    "rules": [
        {
            "description": "", 
            "identifier": "rule_1", 
            "is_active": "true", 
            "output_format": "", 
            "pattern": [
                {
                    "capitalization": [
                        "lower", 
                        "title"
                    ], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "false", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shapes": [], 
                    "suffix": "", 
                    "token": [
                        "Confirmations"
                    ], 
                    "type": "word"
                }, 
                {
                    "capitalization": [], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "false", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shapes": [], 
                    "suffix": "", 
                    "token": [
                        "\n"
                    ], 
                    "type": "word"
                }, 
                {
                    "capitalization": [], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "true", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shape": [], 
                    "suffix": "", 
                    "token": [], 
                    "type": "number"
                }, 
                {
                    "capitalization": [
                        "lower", 
                        "title"
                    ], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "false", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "false", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shapes": [], 
                    "suffix": "", 
                    "token": [
                        "Confirmations"
                    ], 
                    "type": "word"
                }
            ], 
            "polarity": []
        }
    ], 
    "test_text": "Confirmations  353534n", 
    "test_tokens": [
        "Confirmations", 
        "353534n"
    ]
}

text = u"Confirmations \n 34532 confirmations \n \n \n"

d = dict()
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(text, lowercase=False))

config = dict()
config['field_name'] = 'confirmations'

results = c.extract_using_custom_spacy(d, config, field_rules=confirmation_rules)
print json.dumps(results, indent=2)
# Out:
# [
#   {
#     "context": {
#       "end": 4,
#       "tokens_left": [],
#       "text": " <etk 'attribute' = 'confirmations'>Confirmations \n 34532 confirmations</etk> \n\n\n ",
#       "tokens_right": [
#         "\n\n\n"
#       ],
#       "start": 0,
#       "input": "tokens",
#       "identifier": "rule_1",
#       "rule_id": 0
#     },
#     "value": "34532"
#   }
# ]

# %%
text = u"Total Input \n \n 0.5336506 BTC"
field_rules = {
    "field_name": "total_input", 
    "results": [], 
    "rules": [
        {
            "description": "", 
            "identifier": "rule_1", 
            "is_active": "true", 
            "output_format": "{1}{2}{3} {4}", 
            "pattern": [
                {
                    "capitalization": [
                        "lower", 
                        "title"
                    ], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "false", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shapes": [], 
                    "suffix": "", 
                    "token": [
                        "Total"
                    ], 
                    "type": "word"
                }, 
                {
                    "capitalization": [
                        "lower", 
                        "title"
                    ], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "false", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shapes": [], 
                    "suffix": "", 
                    "token": [
                        "Input"
                    ], 
                    "type": "word"
                }, 
                {
                    "capitalization": [], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "false", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shapes": [], 
                    "suffix": "", 
                    "token": [
                        "\n\n"
                    ], 
                    "type": "word"
                }, 
                {
                    "capitalization": [], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "true", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shape": [], 
                    "suffix": "", 
                    "token": [], 
                    "type": "number"
                }, 
                {
                    "capitalization": [], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "true", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shapes": [], 
                    "suffix": "", 
                    "token": [
                        "."
                    ], 
                    "type": "punctuation"
                }, 
                {
                    "capitalization": [], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "true", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shape": [], 
                    "suffix": "", 
                    "token": [], 
                    "type": "number"
                }, 
                {
                    "capitalization": [
                        "upper"
                    ], 
                    "contain_digit": "", 
                    "is_followed_by_space": "false", 
                    "is_in_output": "true", 
                    "is_in_vocabulary": "", 
                    "is_out_of_vocabulary": "", 
                    "is_required": "true", 
                    "length": [], 
                    "maximum": "", 
                    "minimum": "", 
                    "numbers": [], 
                    "part_of_speech": [], 
                    "prefix": "", 
                    "shapes": [], 
                    "suffix": "", 
                    "token": [], 
                    "type": "word"
                }
            ], 
            "polarity": []
        }
    ], 
    "test_text": "Total Input \\n \\n 0.08703713 BTC ", 
    "test_tokens": [
        "Total", 
        "Input", 
        "\\", 
        "n", 
        "\\", 
        "n", 
        "0", 
        ".", 
        "08703713", 
        "BTC"
    ]
}


d = dict()
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(text, lowercase=False))

config = dict()
config['field_name'] = 'total_input'

results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print json.dumps(results, indent=2)
# Out:
# [
#   {
#     "context": {
#       "end": 7,
#       "tokens_left": [],
#       "text": " <etk 'attribute' = 'total_input'>Total Input \n\n 0 . 5336506 BTC</etk>  ",
#       "tokens_right": [],
#       "start": 0,
#       "input": "tokens",
#       "identifier": "rule_1",
#       "rule_id": 0
#     },
#     "value": "0.5336506 BTC"
#   }
# ]
