# %% [markdown]
# This tutorial shows you how to use ETK to extract information for all soccer teams in Italy. Suppose that you want to construct a list of records containing team name, home city, latitude and longitude for every team in Italy.

# %% [markdown]
# We start with a Wikipedia page that lists all soccer teams in Italy:
# https://en.wikipedia.org/wiki/List_of_football_clubs_in_Italy. The page has a table for each division. Each table contains the team name and home city, as well as other information that we will ignore for now. The tables don’t contain the latitude and longitude of the cities. You will notice that most city names in the table are links to other wikipedia pages, and we could get the latitude and longitudes from there. In this tutorial we will use a different approach, linking the city names to geonames.org, a dataset containing every city in the world.

# %% [markdown]
# # Part 1: Extracting The Team Tables

# %% [markdown]
# Look at the page, and you will notice that the teams are scattered over multiple tables, one for each division. Fortunately, all the tables have the same structure, which will make our job easier.

# %% [markdown]
# ## Defining an ETK module

# %% [markdown]
# An ETK module organizes the code for a project so that you can put all the extraction code for a project in a reusable module. Often, large projects will consist of multiple ETK modules for different kinds of documents. In this tutorial we will have only one module

# %% [markdown]
# First, we need to load some dependencies we need to cover through this tutorial. Besides, we create an global variable `etk` which we'll also use through the whole process.

# %%
import requests
import json
import jsonpath_ng.ext as jex
from etk.extractors.table_extractor import TableExtractor
from etk.extractors.glossary_extractor import GlossaryExtractor
from etk.etk import ETK
etk = ETK()

# %% [markdown]
# ## Reading the HTML file

# %%
url = 'https://en.wikipedia.org/wiki/List_of_football_clubs_in_Italy'
response = requests.get(url)
html_page = response.text
html_page
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of football clubs in Italy - Wikipedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_football_clubs_in_Italy","wgTitle":"List of football clubs in Italy","wgCurRevisionId":857361197,"wgRevisionId":857361197,"wgArticleId":1083851,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use dmy dates from June 2013","Football clubs in Italy","Lists of association football clubs","Association football in Italy lists"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"List_of_football_clubs_in_Italy","wgRelevantArticleId":1083851,"wgRequestId":"W5gmpwpAADoAAJzZ78sAAAAV","wgCSPNonce":false,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgCategoryTreePageCategoryOptions":"{\\"mode\\":0,\\"hideprefix\\":20,\\"showcount\\":true,\\"namespaces\\":false}","wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgMFExpandAllSectionsUserOption":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgWikibaseItemId":"Q2214955","wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":true,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.toc.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"});mw.loader.implement("user.tokens@1dqfd7l",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});mw.loader.load(["site","mediawiki.page.startup","mediawiki.user","mediawiki.page.ready","jquery.tablesort ...

# %% [markdown]
# ## Extracting the tables

# %% [markdown]
# Extracting the tables in a Web page is very easy as ETK has a table extractor. We devide this phase into two parts.

# %% [markdown]
# The first part is to create an instance of TableExtractor, and use that instance to extract the raw tables.

# %%
my_table_extractor = TableExtractor()
tables_in_page = my_table_extractor.extract(html_page)[:14]
print('Number of tables in this page:', len(tables_in_page), '\n')
print('The first table in the page shows below: \n')
print(json.dumps(tables_in_page[-1].value, indent=2))
# Out:
# Number of tables in this page: 14
#
# The first table in the page shows below:
#
# {
#   "features": {
#     "no_of_rows": 19,
#     "no_of_cells": 95,
#     "max_cols_in_a_row": 5,
#     "ratio_of_img_tags_to_cells": 0.0,
#     "ratio_of_href_tags_to_cells": 0.5894736842105263,
#     "ratio_of_input_tags_to_cells": 0.0,
#     "ratio_of_select_tags_to_cells": 0.0,
#     "ratio_of_colspan_tags_to_cells": 0.0,
#     "ratio_of_colons_to_cells": 0.0,
#     "avg_cell_len": 12.905263157894737,
#     "avg_row_len": 68.42105263157895,
#     "avg_row_len_dev": 7.759546336069895,
#     "avg_col_len": 245.2,
#     "avg_col_len_dev": 4.051833532486392,
#     "no_of_cols_containing_num": 2,
#     "no_of_cols_empty": 0
#   },
#   "rows": [
#     {
#       "cells": [
#         {
#           "cell": "<th>Club\n</th>",
#           "text": "Club",
#           "id": "row_0_col_0"
#         },
#         {
#           "cell": "<th>City\n</th>",
#           "text": "City",
#           "id": "row_0_col_1"
#         },
#         {
#           "cell": "<th>Stadium\n</th>",
#           "text": "Stadium",
#           "id": "row_0_col_2"
#         },
#         {
#           "cell": "<th>Capacity\n</th>",
#           "text": "Capacity",
#           "id": "row_0_col_3"
#         },
#         {
#           "cell": "<th>2015\u201316 season\n</th>",
#           "text": "2015\u201316 season",
#           "id": "row_0_col_4"
#         }
#       ],
#       "text": "Club | City | Stadium | Capacity | 2015\u201316 season",
#       "html": "<html><body><table><th>Club\n</th>\n<th>City\n</th>\n<th>Stadium\n</th>\n<th>Capacity\n</th>\n<th>2015\u201316 season\n</th>\n</table></body></html>",
#       "id": "row_0"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/S.F._Aversa_Normanna\" title=\"S.F. Aversa Normanna\">Aversa Normanna</a>\n</td>",
#           "text": "Aversa Normanna",
#           "id": "row_1_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Aversa\" title=\"Aversa\">Aversa</a>\n</td>",
#           "text": "Aversa",
#           "id": "row_1_col_1"
#         },
#         {
#           "cell": "<td>Augusto Bisceglia\n</td>",
#           "text": "Augusto Bisceglia",
#           "id": "row_1_col_2"
#         },
#         {
#           "cell": "<td>2,555\n</td>",
#           "text": "2,555",
#           "id": "row_1_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">6th in Serie D Girone I</a>\n</td>",
#           "text": "6th in Serie D Girone I",
#           "id": "row_1_col_4"
#         }
#       ],
#       "text": "Aversa Normanna | Aversa | Augusto Bisceglia | 2,555 | 6th in Serie D Girone I",
#       "html": "<html><body><table><td><a href=\"/wiki/S.F._Aversa_Normanna\" title=\"S.F. Aversa Normanna\">Aversa Normanna</a>\n</td>\n<td><a href=\"/wiki/Aversa\" title=\"Aversa\">Aversa</a>\n</td>\n<td>Augusto Bisceglia\n</td>\n<td>2,555\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">6th in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_1"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/U.S._Castrovillari_Calcio\" title=\"U.S. Castrovillari Calcio\">Castrovillari</a>\n</td>",
#           "text": "Castrovillari",
#           "id": "row_2_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Castrovillari\" title=\"Castrovillari\">Castrovillari</a>\n</td>",
#           "text": "Castrovillari",
#           "id": "row_2_col_1"
#         },
#         {
#           "cell": "<td>Mimmo Rende\n</td>",
#           "text": "Mimmo Rende",
#           "id": "row_2_col_2"
#         },
#         {
#           "cell": "<td>4,000\n</td>",
#           "text": "4,000",
#           "id": "row_2_col_3"
#         },
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">2nd in Eccellenza Calabria</a>\n</td>",
#           "text": "2nd in Eccellenza Calabria",
#           "id": "row_2_col_4"
#         }
#       ],
#       "text": "Castrovillari | Castrovillari | Mimmo Rende | 4,000 | 2nd in Eccellenza Calabria",
#       "html": "<html><body><table><td><a href=\"/wiki/U.S._Castrovillari_Calcio\" title=\"U.S. Castrovillari Calcio\">Castrovillari</a>\n</td>\n<td><a href=\"/wiki/Castrovillari\" title=\"Castrovillari\">Castrovillari</a>\n</td>\n<td>Mimmo Rende\n</td>\n<td>4,000\n</td>\n<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">2nd in Eccellenza Calabria</a>\n</td>\n</table></body></html>",
#       "id": "row_2"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a class=\"mw-redirect\" href=\"/wiki/U.S.D._Cavese_1919\" title=\"U.S.D. Cavese 1919\">Cavese</a>\n</td>",
#           "text": "Cavese",
#           "id": "row_3_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Cava_de%27_Tirreni\" title=\"Cava de' Tirreni\">Cava de' Tirreni</a>\n</td>",
#           "text": "Cava de' Tirreni",
#           "id": "row_3_col_1"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Stadio_Simonetta_Lamberti\" title=\"Stadio Simonetta Lamberti\">Simonetta Lamberti</a>\n</td>",
#           "text": "Simonetta Lamberti",
#           "id": "row_3_col_2"
#         },
#         {
#           "cell": "<td>5,200\n</td>",
#           "text": "5,200",
#           "id": "row_3_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">3rd in Serie D Girone I</a>\n</td>",
#           "text": "3rd in Serie D Girone I",
#           "id": "row_3_col_4"
#         }
#       ],
#       "text": "Cavese | Cava de' Tirreni | Simonetta Lamberti | 5,200 | 3rd in Serie D Girone I",
#       "html": "<html><body><table><td><a class=\"mw-redirect\" href=\"/wiki/U.S.D._Cavese_1919\" title=\"U.S.D. Cavese 1919\">Cavese</a>\n</td>\n<td><a href=\"/wiki/Cava_de%27_Tirreni\" title=\"Cava de' Tirreni\">Cava de' Tirreni</a>\n</td>\n<td><a href=\"/wiki/Stadio_Simonetta_Lamberti\" title=\"Stadio Simonetta Lamberti\">Simonetta Lamberti</a>\n</td>\n<td>5,200\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">3rd in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_3"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/A.S.D._Due_Torri\" title=\"A.S.D. Due Torri\">Due Torri</a>\n</td>",
#           "text": "Due Torri",
#           "id": "row_4_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Piraino\" title=\"Piraino\">Piraino</a>\n</td>",
#           "text": "Piraino",
#           "id": "row_4_col_1"
#         },
#         {
#           "cell": "<td>Enzo Vasi\n</td>",
#           "text": "Enzo Vasi",
#           "id": "row_4_col_2"
#         },
#         {
#           "cell": "<td>3,800\n</td>",
#           "text": "3,800",
#           "id": "row_4_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">7th in Serie D Girone I</a>\n</td>",
#           "text": "7th in Serie D Girone I",
#           "id": "row_4_col_4"
#         }
#       ],
#       "text": "Due Torri | Piraino | Enzo Vasi | 3,800 | 7th in Serie D Girone I",
#       "html": "<html><body><table><td><a href=\"/wiki/A.S.D._Due_Torri\" title=\"A.S.D. Due Torri\">Due Torri</a>\n</td>\n<td><a href=\"/wiki/Piraino\" title=\"Piraino\">Piraino</a>\n</td>\n<td>Enzo Vasi\n</td>\n<td>3,800\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">7th in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_4"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/A.S.D._Nerostellati_Frattese\" title=\"A.S.D. Nerostellati Frattese\">Frattese</a>\n</td>",
#           "text": "Frattese",
#           "id": "row_5_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Frattamaggiore\" title=\"Frattamaggiore\">Frattamaggiore</a>\n</td>",
#           "text": "Frattamaggiore",
#           "id": "row_5_col_1"
#         },
#         {
#           "cell": "<td>Pasquale Ianniello\n</td>",
#           "text": "Pasquale Ianniello",
#           "id": "row_5_col_2"
#         },
#         {
#           "cell": "<td>5,000\n</td>",
#           "text": "5,000",
#           "id": "row_5_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">2nd in Serie D Girone I</a>\n</td>",
#           "text": "2nd in Serie D Girone I",
#           "id": "row_5_col_4"
#         }
#       ],
#       "text": "Frattese | Frattamaggiore | Pasquale Ianniello | 5,000 | 2nd in Serie D Girone I",
#       "html": "<html><body><table><td><a href=\"/wiki/A.S.D._Nerostellati_Frattese\" title=\"A.S.D. Nerostellati Frattese\">Frattese</a>\n</td>\n<td><a href=\"/wiki/Frattamaggiore\" title=\"Frattamaggiore\">Frattamaggiore</a>\n</td>\n<td>Pasquale Ianniello\n</td>\n<td>5,000\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">2nd in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_5"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a class=\"mw-redirect\" href=\"/wiki/Gela_Calcio\" title=\"Gela Calcio\">Gela</a>\n</td>",
#           "text": "Gela",
#           "id": "row_6_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Gela\" title=\"Gela\">Gela</a>\n</td>",
#           "text": "Gela",
#           "id": "row_6_col_1"
#         },
#         {
#           "cell": "<td>Vincenzo Presti\n</td>",
#           "text": "Vincenzo Presti",
#           "id": "row_6_col_2"
#         },
#         {
#           "cell": "<td>4,200\n</td>",
#           "text": "4,200",
#           "id": "row_6_col_3"
#         },
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">1st in Eccellenza Sicily Girone A</a>\n</td>",
#           "text": "1st in Eccellenza Sicily Girone A",
#           "id": "row_6_col_4"
#         }
#       ],
#       "text": "Gela | Gela | Vincenzo Presti | 4,200 | 1st in Eccellenza Sicily Girone A",
#       "html": "<html><body><table><td><a class=\"mw-redirect\" href=\"/wiki/Gela_Calcio\" title=\"Gela Calcio\">Gela</a>\n</td>\n<td><a href=\"/wiki/Gela\" title=\"Gela\">Gela</a>\n</td>\n<td>Vincenzo Presti\n</td>\n<td>4,200\n</td>\n<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">1st in Eccellenza Sicily Girone A</a>\n</td>\n</table></body></html>",
#       "id": "row_6"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/A.S.D._S.F._Gladiator_1912\" title=\"A.S.D. S.F. Gladiator 1912\">Gladiator</a>\n</td>",
#           "text": "Gladiator",
#           "id": "row_7_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Santa_Maria_Capua_Vetere\" title=\"Santa Maria Capua Vetere\">Santa Maria Capua Vetere</a>\n</td>",
#           "text": "Santa Maria Capua Vetere",
#           "id": "row_7_col_1"
#         },
#         {
#           "cell": "<td>Mario Piccirillo\n</td>",
#           "text": "Mario Piccirillo",
#           "id": "row_7_col_2"
#         },
#         {
#           "cell": "<td>2,000\n</td>",
#           "text": "2,000",
#           "id": "row_7_col_3"
#         },
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">12th in Eccellenza Campania Girone A</a>\n</td>",
#           "text": "12th in Eccellenza Campania Girone A",
#           "id": "row_7_col_4"
#         }
#       ],
#       "text": "Gladiator | Santa Maria Capua Vetere | Mario Piccirillo | 2,000 | 12th in Eccellenza Campania Girone A",
#       "html": "<html><body><table><td><a href=\"/wiki/A.S.D._S.F._Gladiator_1912\" title=\"A.S.D. S.F. Gladiator 1912\">Gladiator</a>\n</td>\n<td><a href=\"/wiki/Santa_Maria_Capua_Vetere\" title=\"Santa Maria Capua Vetere\">Santa Maria Capua Vetere</a>\n</td>\n<td>Mario Piccirillo\n</td>\n<td>2,000\n</td>\n<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">12th in Eccellenza Campania Girone A</a>\n</td>\n</table></body></html>",
#       "id": "row_7"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/A.S.D._Gragnano_Calcio\" title=\"A.S.D. Gragnano Calcio\">Gragnano</a>\n</td>",
#           "text": "Gragnano",
#           "id": "row_8_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Gragnano\" title=\"Gragnano\">Gragnano</a>\n</td>",
#           "text": "Gragnano",
#           "id": "row_8_col_1"
#         },
#         {
#           "cell": "<td>San Michele\n</td>",
#           "text": "San Michele",
#           "id": "row_8_col_2"
#         },
#         {
#           "cell": "<td>2,000\n</td>",
#           "text": "2,000",
#           "id": "row_8_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">10th in Serie D Girone I</a>\n</td>",
#           "text": "10th in Serie D Girone I",
#           "id": "row_8_col_4"
#         }
#       ],
#       "text": "Gragnano | Gragnano | San Michele | 2,000 | 10th in Serie D Girone I",
#       "html": "<html><body><table><td><a href=\"/wiki/A.S.D._Gragnano_Calcio\" title=\"A.S.D. Gragnano Calcio\">Gragnano</a>\n</td>\n<td><a href=\"/wiki/Gragnano\" title=\"Gragnano\">Gragnano</a>\n</td>\n<td>San Michele\n</td>\n<td>2,000\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">10th in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_8"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/A.S.D._Igea_Virtus_Barcellona\" title=\"A.S.D. Igea Virtus Barcellona\">Igea Virtus</a>\n</td>",
#           "text": "Igea Virtus",
#           "id": "row_9_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Barcellona_Pozzo_di_Gotto\" title=\"Barcellona Pozzo di Gotto\">Barcellona Pozzo di Gotto</a>\n</td>",
#           "text": "Barcellona Pozzo di Gotto",
#           "id": "row_9_col_1"
#         },
#         {
#           "cell": "<td>Carlo Stagno d'Alcontres\n</td>",
#           "text": "Carlo Stagno d'Alcontres",
#           "id": "row_9_col_2"
#         },
#         {
#           "cell": "<td>7,000\n</td>",
#           "text": "7,000",
#           "id": "row_9_col_3"
#         },
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">1st in Eccellenza Sicily Girone B</a>\n</td>",
#           "text": "1st in Eccellenza Sicily Girone B",
#           "id": "row_9_col_4"
#         }
#       ],
#       "text": "Igea Virtus | Barcellona Pozzo di Gotto | Carlo Stagno d'Alcontres | 7,000 | 1st in Eccellenza Sicily Girone B",
#       "html": "<html><body><table><td><a href=\"/wiki/A.S.D._Igea_Virtus_Barcellona\" title=\"A.S.D. Igea Virtus Barcellona\">Igea Virtus</a>\n</td>\n<td><a href=\"/wiki/Barcellona_Pozzo_di_Gotto\" title=\"Barcellona Pozzo di Gotto\">Barcellona Pozzo di Gotto</a>\n</td>\n<td>Carlo Stagno d'Alcontres\n</td>\n<td>7,000\n</td>\n<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">1st in Eccellenza Sicily Girone B</a>\n</td>\n</table></body></html>",
#       "id": "row_9"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/U.S._Palmese_1912\" title=\"U.S. Palmese 1912\">Palmese</a>\n</td>",
#           "text": "Palmese",
#           "id": "row_10_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Palmi\" title=\"Palmi\">Palmi</a>\n</td>",
#           "text": "Palmi",
#           "id": "row_10_col_1"
#         },
#         {
#           "cell": "<td>Giuseppe Lopresti\n</td>",
#           "text": "Giuseppe Lopresti",
#           "id": "row_10_col_2"
#         },
#         {
#           "cell": "<td>2,500\n</td>",
#           "text": "2,500",
#           "id": "row_10_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">16th in Serie D Girone I</a>\n</td>",
#           "text": "16th in Serie D Girone I",
#           "id": "row_10_col_4"
#         }
#       ],
#       "text": "Palmese | Palmi | Giuseppe Lopresti | 2,500 | 16th in Serie D Girone I",
#       "html": "<html><body><table><td><a href=\"/wiki/U.S._Palmese_1912\" title=\"U.S. Palmese 1912\">Palmese</a>\n</td>\n<td><a href=\"/wiki/Palmi\" title=\"Palmi\">Palmi</a>\n</td>\n<td>Giuseppe Lopresti\n</td>\n<td>2,500\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">16th in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_10"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/A.S.D.C._Pomigliano\" title=\"A.S.D.C. Pomigliano\">Pomigliano</a>\n</td>",
#           "text": "Pomigliano",
#           "id": "row_11_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Pomigliano_d%27Arco\" title=\"Pomigliano d'Arco\">Pomigliano d'Arco</a>\n</td>",
#           "text": "Pomigliano d'Arco",
#           "id": "row_11_col_1"
#         },
#         {
#           "cell": "<td>Ugo Gobbato\n</td>",
#           "text": "Ugo Gobbato",
#           "id": "row_11_col_2"
#         },
#         {
#           "cell": "<td>1,600\n</td>",
#           "text": "1,600",
#           "id": "row_11_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">7th in Serie D Girone H</a>\n</td>",
#           "text": "7th in Serie D Girone H",
#           "id": "row_11_col_4"
#         }
#       ],
#       "text": "Pomigliano | Pomigliano d'Arco | Ugo Gobbato | 1,600 | 7th in Serie D Girone H",
#       "html": "<html><body><table><td><a href=\"/wiki/A.S.D.C._Pomigliano\" title=\"A.S.D.C. Pomigliano\">Pomigliano</a>\n</td>\n<td><a href=\"/wiki/Pomigliano_d%27Arco\" title=\"Pomigliano d'Arco\">Pomigliano d'Arco</a>\n</td>\n<td>Ugo Gobbato\n</td>\n<td>1,600\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">7th in Serie D Girone H</a>\n</td>\n</table></body></html>",
#       "id": "row_11"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a class=\"mw-redirect\" href=\"/wiki/S.S._Rende\" title=\"S.S. Rende\">Rende</a>\n</td>",
#           "text": "Rende",
#           "id": "row_12_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Rende\" title=\"Rende\">Rende</a>\n</td>",
#           "text": "Rende",
#           "id": "row_12_col_1"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Stadio_Marco_Lorenzon\" title=\"Stadio Marco Lorenzon\">Marco Lorenzon</a>\n</td>",
#           "text": "Marco Lorenzon",
#           "id": "row_12_col_2"
#         },
#         {
#           "cell": "<td>5,000\n</td>",
#           "text": "5,000",
#           "id": "row_12_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">11th in Serie D Girone I</a>\n</td>",
#           "text": "11th in Serie D Girone I",
#           "id": "row_12_col_4"
#         }
#       ],
#       "text": "Rende | Rende | Marco Lorenzon | 5,000 | 11th in Serie D Girone I",
#       "html": "<html><body><table><td><a class=\"mw-redirect\" href=\"/wiki/S.S._Rende\" title=\"S.S. Rende\">Rende</a>\n</td>\n<td><a href=\"/wiki/Rende\" title=\"Rende\">Rende</a>\n</td>\n<td><a href=\"/wiki/Stadio_Marco_Lorenzon\" title=\"Stadio Marco Lorenzon\">Marco Lorenzon</a>\n</td>\n<td>5,000\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">11th in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_12"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/A.S.D._Roccella\" title=\"A.S.D. Roccella\">Roccella</a>\n</td>",
#           "text": "Roccella",
#           "id": "row_13_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Roccella_Ionica\" title=\"Roccella Ionica\">Roccella Ionica</a>\n</td>",
#           "text": "Roccella Ionica",
#           "id": "row_13_col_1"
#         },
#         {
#           "cell": "<td>Ninetto Muscolo\n</td>",
#           "text": "Ninetto Muscolo",
#           "id": "row_13_col_2"
#         },
#         {
#           "cell": "<td>2,000\n</td>",
#           "text": "2,000",
#           "id": "row_13_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">8th in Serie D Girone I</a>\n</td>",
#           "text": "8th in Serie D Girone I",
#           "id": "row_13_col_4"
#         }
#       ],
#       "text": "Roccella | Roccella Ionica | Ninetto Muscolo | 2,000 | 8th in Serie D Girone I",
#       "html": "<html><body><table><td><a href=\"/wiki/A.S.D._Roccella\" title=\"A.S.D. Roccella\">Roccella</a>\n</td>\n<td><a href=\"/wiki/Roccella_Ionica\" title=\"Roccella Ionica\">Roccella Ionica</a>\n</td>\n<td>Ninetto Muscolo\n</td>\n<td>2,000\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">8th in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_13"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=A.S.D._Sancataldese_Calcio&amp;action=edit&amp;redlink=1\" title=\"A.S.D. Sancataldese Calcio (page does not exist)\">Sancataldese</a>\n</td>",
#           "text": "Sancataldese",
#           "id": "row_14_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/San_Cataldo,_Sicily\" title=\"San Cataldo, Sicily\">San Cataldo</a>\n</td>",
#           "text": "San Cataldo",
#           "id": "row_14_col_1"
#         },
#         {
#           "cell": "<td>Valentino Mazzola\n</td>",
#           "text": "Valentino Mazzola",
#           "id": "row_14_col_2"
#         },
#         {
#           "cell": "<td>\n</td>",
#           "text": "",
#           "id": "row_14_col_3"
#         },
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">2nd in Eccellenza Sicily Girone A</a>\n</td>",
#           "text": "2nd in Eccellenza Sicily Girone A",
#           "id": "row_14_col_4"
#         }
#       ],
#       "text": "Sancataldese | San Cataldo | Valentino Mazzola |  | 2nd in Eccellenza Sicily Girone A",
#       "html": "<html><body><table><td><a class=\"new\" href=\"/w/index.php?title=A.S.D._Sancataldese_Calcio&amp;action=edit&amp;redlink=1\" title=\"A.S.D. Sancataldese Calcio (page does not exist)\">Sancataldese</a>\n</td>\n<td><a href=\"/wiki/San_Cataldo,_Sicily\" title=\"San Cataldo, Sicily\">San Cataldo</a>\n</td>\n<td>Valentino Mazzola\n</td>\n<td>\n</td>\n<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">2nd in Eccellenza Sicily Girone A</a>\n</td>\n</table></body></html>",
#       "id": "row_14"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/A.S.D._Pol._Sarnese_Calcio\" title=\"A.S.D. Pol. Sarnese Calcio\">Sarnese</a>\n</td>",
#           "text": "Sarnese",
#           "id": "row_15_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Sarno\" title=\"Sarno\">Sarno</a>\n</td>",
#           "text": "Sarno",
#           "id": "row_15_col_1"
#         },
#         {
#           "cell": "<td>Felice Squitieri\n</td>",
#           "text": "Felice Squitieri",
#           "id": "row_15_col_2"
#         },
#         {
#           "cell": "<td>3,246\n</td>",
#           "text": "3,246",
#           "id": "row_15_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">9th in Serie D Girone I</a>\n</td>",
#           "text": "9th in Serie D Girone I",
#           "id": "row_15_col_4"
#         }
#       ],
#       "text": "Sarnese | Sarno | Felice Squitieri | 3,246 | 9th in Serie D Girone I",
#       "html": "<html><body><table><td><a href=\"/wiki/A.S.D._Pol._Sarnese_Calcio\" title=\"A.S.D. Pol. Sarnese Calcio\">Sarnese</a>\n</td>\n<td><a href=\"/wiki/Sarno\" title=\"Sarno\">Sarno</a>\n</td>\n<td>Felice Squitieri\n</td>\n<td>3,246\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">9th in Serie D Girone I</a>\n</td>\n</table></body></html>",
#       "id": "row_15"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=A.S._Sersale&amp;action=edit&amp;redlink=1\" title=\"A.S. Sersale (page does not exist)\">Sersale</a>\n</td>",
#           "text": "Sersale",
#           "id": "row_16_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Sersale\" title=\"Sersale\">Sersale</a>\n</td>",
#           "text": "Sersale",
#           "id": "row_16_col_1"
#         },
#         {
#           "cell": "<td>Ferrarizzi\n</td>",
#           "text": "Ferrarizzi",
#           "id": "row_16_col_2"
#         },
#         {
#           "cell": "<td>\n</td>",
#           "text": "",
#           "id": "row_16_col_3"
#         },
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">1st in Eccellenza Calabria</a>\n</td>",
#           "text": "1st in Eccellenza Calabria",
#           "id": "row_16_col_4"
#         }
#       ],
#       "text": "Sersale | Sersale | Ferrarizzi |  | 1st in Eccellenza Calabria",
#       "html": "<html><body><table><td><a class=\"new\" href=\"/w/index.php?title=A.S._Sersale&amp;action=edit&amp;redlink=1\" title=\"A.S. Sersale (page does not exist)\">Sersale</a>\n</td>\n<td><a href=\"/wiki/Sersale\" title=\"Sersale\">Sersale</a>\n</td>\n<td>Ferrarizzi\n</td>\n<td>\n</td>\n<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">1st in Eccellenza Calabria</a>\n</td>\n</table></body></html>",
#       "id": "row_16"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a class=\"mw-redirect\" href=\"/wiki/A.S.D._Sicula_Leonzio\" title=\"A.S.D. Sicula Leonzio\">Sicula Leonzio</a>\n</td>",
#           "text": "Sicula Leonzio",
#           "id": "row_17_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Lentini\" title=\"Lentini\">Lentini</a>\n</td>",
#           "text": "Lentini",
#           "id": "row_17_col_1"
#         },
#         {
#           "cell": "<td>Angelino Nobile\n</td>",
#           "text": "Angelino Nobile",
#           "id": "row_17_col_2"
#         },
#         {
#           "cell": "<td>2,500\n</td>",
#           "text": "2,500",
#           "id": "row_17_col_3"
#         },
#         {
#           "cell": "<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">3rd in Eccellenza Sicily Girone B</a>\n</td>",
#           "text": "3rd in Eccellenza Sicily Girone B",
#           "id": "row_17_col_4"
#         }
#       ],
#       "text": "Sicula Leonzio | Lentini | Angelino Nobile | 2,500 | 3rd in Eccellenza Sicily Girone B",
#       "html": "<html><body><table><td><a class=\"mw-redirect\" href=\"/wiki/A.S.D._Sicula_Leonzio\" title=\"A.S.D. Sicula Leonzio\">Sicula Leonzio</a>\n</td>\n<td><a href=\"/wiki/Lentini\" title=\"Lentini\">Lentini</a>\n</td>\n<td>Angelino Nobile\n</td>\n<td>2,500\n</td>\n<td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">3rd in Eccellenza Sicily Girone B</a>\n</td>\n</table></body></html>",
#       "id": "row_17"
#     },
#     {
#       "cells": [
#         {
#           "cell": "<td><a href=\"/wiki/F.C._Turris_1944\" title=\"F.C. Turris 1944\">Turris</a>\n</td>",
#           "text": "Turris",
#           "id": "row_18_col_0"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/Torre_del_Greco\" title=\"Torre del Greco\">Torre del Greco</a>\n</td>",
#           "text": "Torre del Greco",
#           "id": "row_18_col_1"
#         },
#         {
#           "cell": "<td>Amerigo Liguori\n</td>",
#           "text": "Amerigo Liguori",
#           "id": "row_18_col_2"
#         },
#         {
#           "cell": "<td>5,300\n</td>",
#           "text": "5,300",
#           "id": "row_18_col_3"
#         },
#         {
#           "cell": "<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">13th in Serie D Girone H</a>\n</td>",
#           "text": "13th in Serie D Girone H",
#           "id": "row_18_col_4"
#         }
#       ],
#       "text": "Turris | Torre del Greco | Amerigo Liguori | 5,300 | 13th in Serie D Girone H",
#       "html": "<html><body><table><td><a href=\"/wiki/F.C._Turris_1944\" title=\"F.C. Turris 1944\">Turris</a>\n</td>\n<td><a href=\"/wiki/Torre_del_Greco\" title=\"Torre del Greco\">Torre del Greco</a>\n</td>\n<td>Amerigo Liguori\n</td>\n<td>5,300\n</td>\n<td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">13th in Serie D Girone H</a>\n</td>\n</table></body></html>",
#       "id": "row_18"
#     }
#   ],
#   "context_before": "] edit [ Girone I",
#   "context_after": "Club City Stadium Capacity",
#   "fingerprint": "-000-1-10th-11th-12th-13th-16-16th-1912-1919-1944-1st-2-200-2015-246-27Arco-27_Tirreni-2nd-3-300-3rd-4-5-500-555-600-6th-7-7th-80-800-8th-9316_Eccellenza-9316_Serie_D-9th-A-Alcontres-Amerigo-Angelino-Arco-Augusto-Aversa-B-Barcellona-Barcellona_Pozzo_di_Gotto-Bisceglia-C-Calabria-Calcio-Campania-Capacity-Capua-Carlo-Castrovillari-Cataldo-Cava-Cava_de-Cavese-City-Club-D-Due-E2-Eccellenza-Enzo-F-Felice-Ferrarizzi-Frattamaggiore-Frattese-Gela-Gela_Calcio-Girone-Giuseppe-Gladiator-Gobbato-Gotto-Gragnano-Greco-H-I-Ianniello-Igea-Ionica-Lamberti-Lentini-Leonzio-Liguori-Lopresti-Lorenzon-Marco-Maria-Mario-Mazzola-Michele-Mimmo-Muscolo-Nerostellati-Ninetto-Nobile-Normanna-Palmese-Palmi-Pasquale-Piccirillo-Piraino-Pol-Pomigliano-Pomigliano_d-Pozzo-Presti-Rende-Roccella-Roccella_Ionica-S-San-San_Cataldo-Sancataldese-Santa-Santa_Maria_Capua_Vetere-Sarnese-Sarno-Serie-Sersale-Sicily-Sicula-Simonetta-Squitieri-Stadio-Stadio_Marco_Lorenzon-Stadio_Simonetta_Lamberti-Stadium-Stagno-Tirreni-Torre-Torre_del_Greco-Torri-Turris-U-Ugo-Valentino-Vasi-Vetere-Vincenzo-Virtus-_Aversa_Normanna-_Castrovillari_Calcio-_Cavese_1919-_Due_Torri-_Gladiator_1912-_Gragnano_Calcio-_Igea_Virtus_Barcellona-_Nerostellati_Frattese-_Palmese_1912-_Pol-_Pomigliano-_Rende-_Roccella-_S-_Sancataldese_Calcio-_Sarnese_Calcio-_Sersale-_Sicily-_Sicula_Leonzio-_Turris_1944-a-action-amp-class-d-de-del-di-does-edit-exist-href-in-index-mw-new-not-page-php-redirect-redlink-season-table-td-th-title-tr-w-wiki",
#   "html": "<table><tr><th>Club\n</th><th>City\n</th><th>Stadium\n</th><th>Capacity\n</th><th>2015\u201316 season\n</th></tr><tr><td><a href=\"/wiki/S.F._Aversa_Normanna\" title=\"S.F. Aversa Normanna\">Aversa Normanna</a>\n</td><td><a href=\"/wiki/Aversa\" title=\"Aversa\">Aversa</a>\n</td><td>Augusto Bisceglia\n</td><td>2,555\n</td><td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">6th in Serie D Girone I</a>\n</td></tr><tr><td><a href=\"/wiki/U.S._Castrovillari_Calcio\" title=\"U.S. Castrovillari Calcio\">Castrovillari</a>\n</td><td><a href=\"/wiki/Castrovillari\" title=\"Castrovillari\">Castrovillari</a>\n</td><td>Mimmo Rende\n</td><td>4,000\n</td><td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">2nd in Eccellenza Calabria</a>\n</td></tr><tr><td><a class=\"mw-redirect\" href=\"/wiki/U.S.D._Cavese_1919\" title=\"U.S.D. Cavese 1919\">Cavese</a>\n</td><td><a href=\"/wiki/Cava_de%27_Tirreni\" title=\"Cava de' Tirreni\">Cava de' Tirreni</a>\n</td><td><a href=\"/wiki/Stadio_Simonetta_Lamberti\" title=\"Stadio Simonetta Lamberti\">Simonetta Lamberti</a>\n</td><td>5,200\n</td><td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">3rd in Serie D Girone I</a>\n</td></tr><tr><td><a href=\"/wiki/A.S.D._Due_Torri\" title=\"A.S.D. Due Torri\">Due Torri</a>\n</td><td><a href=\"/wiki/Piraino\" title=\"Piraino\">Piraino</a>\n</td><td>Enzo Vasi\n</td><td>3,800\n</td><td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">7th in Serie D Girone I</a>\n</td></tr><tr><td><a href=\"/wiki/A.S.D._Nerostellati_Frattese\" title=\"A.S.D. Nerostellati Frattese\">Frattese</a>\n</td><td><a href=\"/wiki/Frattamaggiore\" title=\"Frattamaggiore\">Frattamaggiore</a>\n</td><td>Pasquale Ianniello\n</td><td>5,000\n</td><td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">2nd in Serie D Girone I</a>\n</td></tr><tr><td><a class=\"mw-redirect\" href=\"/wiki/Gela_Calcio\" title=\"Gela Calcio\">Gela</a>\n</td><td><a href=\"/wiki/Gela\" title=\"Gela\">Gela</a>\n</td><td>Vincenzo Presti\n</td><td>4,200\n</td><td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">1st in Eccellenza Sicily Girone A</a>\n</td></tr><tr><td><a href=\"/wiki/A.S.D._S.F._Gladiator_1912\" title=\"A.S.D. S.F. Gladiator 1912\">Gladiator</a>\n</td><td><a href=\"/wiki/Santa_Maria_Capua_Vetere\" title=\"Santa Maria Capua Vetere\">Santa Maria Capua Vetere</a>\n</td><td>Mario Piccirillo\n</td><td>2,000\n</td><td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">12th in Eccellenza Campania Girone A</a>\n</td></tr><tr><td><a href=\"/wiki/A.S.D._Gragnano_Calcio\" title=\"A.S.D. Gragnano Calcio\">Gragnano</a>\n</td><td><a href=\"/wiki/Gragnano\" title=\"Gragnano\">Gragnano</a>\n</td><td>San Michele\n</td><td>2,000\n</td><td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">10th in Serie D Girone I</a>\n</td></tr><tr><td><a href=\"/wiki/A.S.D._Igea_Virtus_Barcellona\" title=\"A.S.D. Igea Virtus Barcellona\">Igea Virtus</a>\n</td><td><a href=\"/wiki/Barcellona_Pozzo_di_Gotto\" title=\"Barcellona Pozzo di Gotto\">Barcellona Pozzo di Gotto</a>\n</td><td>Carlo Stagno d'Alcontres\n</td><td>7,000\n</td><td><a class=\"new\" href=\"/w/index.php?title=2015%E2%80%9316_Eccellenza&amp;action=edit&amp;redlink=1\" title=\"2015\u201316 Eccellenza (page does not exist)\">1st in Eccellenza Sicily Girone B</a>\n</td></tr><tr><td><a href=\"/wiki/U.S._Palmese_1912\" title=\"U.S. Palmese 1912\">Palmese</a>\n</td><td><a href=\"/wiki/Palmi\" title=\"Palmi\">Palmi</a>\n</td><td>Giuseppe Lopresti\n</td><td>2,500\n</td><td><a href=\"/wiki/2015%E2%80%9316_Serie_D\" title=\"2015\u201316 Serie D\">16 ...
#   "text": "Club | City | Stadium | Capacity | 2015\u201316 season\nAversa Normanna | Aversa | Augusto Bisceglia | 2,555 | 6th in Serie D Girone I\nCastrovillari | Castrovillari | Mimmo Rende | 4,000 | 2nd in Eccellenza Calabria\nCavese | Cava de' Tirreni | Simonetta Lamberti | 5,200 | 3rd in Serie D Girone I\nDue Torri | Piraino | Enzo Vasi | 3,800 | 7th in Serie D Girone I\nFrattese | Frattamaggiore | Pasquale Ianniello | 5,000 | 2nd in Serie D Girone I\nGela | Gela | Vincenzo Presti | 4,200 | 1st in Eccellenza Sicily Girone A\nGladiator | Santa Maria Capua Vetere | Mario Piccirillo | 2,000 | 12th in Eccellenza Campania Girone A\nGragnano | Gragnano | San Michele | 2,000 | 10th in Serie D Girone I\nIgea Virtus | Barcellona Pozzo di Gotto | Carlo Stagno d'Alcontres | 7,000 | 1st in Eccellenza Sicily Girone B\nPalmese | Palmi | Giuseppe Lopresti | 2,500 | 16th in Serie D Girone I\nPomigliano | Pomigliano d'Arco | Ugo Gobbato | 1,600 | 7th in Serie D Girone H\nRende | Rende | Marco Lorenzon | 5,000 | 11th in Serie D Girone I\nRoccella | Roccella Ionica | Ninetto Muscolo | 2,000 | 8th in Serie D Girone I\nSancataldese | San Cataldo | Valentino Mazzola |  | 2nd in Eccellenza Sicily Girone A\nSarnese | Sarno | Felice Squitieri | 3,246 | 9th in Serie D Girone I\nSersale | Sersale | Ferrarizzi |  | 1st in Eccellenza Calabria\nSicula Leonzio | Lentini | Angelino Nobile | 2,500 | 3rd in Eccellenza Sicily Girone B\nTurris | Torre del Greco | Amerigo Liguori | 5,300 | 13th in Serie D Girone H\n"
# }

# %% [markdown]
# In the second part, we use JSON path to do further table extraction.
#
# Aside: ETK uses JSON paths to access data in JSON documents. Take a look at the excellent and short introduction to JSON paths: http://goessner.net/articles/JsonPath/

# %%
extracted_rows = list()
json_path = '$.rows[*].cells[0:4].text'
keys = ['Team', 'City', 'Stadium', 'Capacity']
for table in tables_in_page:
    doc = etk.create_document(table.value)
    row_values = doc.select_segments(json_path)[4:]
    cell_cnt = 0
    for index in range(0, len(row_values), 4):
        one_row = {keys[0]: row_values[index].value,
                   keys[1]: row_values[index + 1].value,
                   keys[2]: row_values[index + 2].value,
                   keys[3]: row_values[index + 3].value}
        extracted_rows.append(one_row)
print('Number of rows extracted from that page', len(extracted_cells), '\n')
print('Sample rows(5):')
print(json.dumps(extracted_rows[:5], indent=2))
# Out:
# Number of rows extracted from that page 261
#
# Sample rows(5):
# [
#   {
#     "Team": "Atalanta",
#     "City": "Bergamo",
#     "Stadium": "Stadio Atleti Azzurri d'Italia",
#     "Capacity": "7004213000000000000\u2660 21,300"
#   },
#   {
#     "Team": "Bologna",
#     "City": "Bologna",
#     "Stadium": "Stadio Renato Dall'Ara",
#     "Capacity": "7004382790000000000\u2660 38,279"
#   },
#   {
#     "Team": "Cagliari",
#     "City": "Cagliari",
#     "Stadium": "Sardegna Arena",
#     "Capacity": "7004162330000000000\u2660 16,233"
#   },
#   {
#     "Team": "Chievo",
#     "City": "Verona",
#     "Stadium": "Stadio Marc'Antonio Bentegodi",
#     "Capacity": "7004384020000000000\u2660 38,402"
#   },
#   {
#     "Team": "Empoli",
#     "City": "Empoli",
#     "Stadium": "Stadio Carlo Castellani",
#     "Capacity": "7004162840000000000\u2660 16,284"
#   }
# ]

# %% [markdown]
# The extracted tables are now stored in your JSON document.

# %% [markdown]
# construct a dict that maps city names to all geonames records that contain the city name with population greater than 25,000.

# %%
file_name = 'cities_ppl>25000.json'
file = open(file_name, 'r')
city_dataset = json.loads(file.read())
file.close()
city_list = list(city_dataset.keys())
print('There are', len(city_list), 'cities with population great than or equal to 25,000.\n')
print('City list samples(10):\n')
print(city_list[:10])
# Out:
# There are 15117 cities with population great than or equal to 25,000.
#
# City list samples(10):
#
# ['Marion', 'Fes', 'Fes al Bali', 'Gravina in Puglia', 'Nawada', 'Pensacola', 'Pedro Betancourt', 'Uriangato', 'Fiditi', 'Wilkes-Barre']

# %% [markdown]
# ## Identifying the city names in geonames and linking to geonames

# %% [markdown]
# There are many ways to do this step. We will do it using the ETK glossary extractor to illustrate how to use other extractors and how to chain the results of one extractor as input to other extractors.
#
# Using data from the geonames.org web site, we prepared a list of all cities in the world with population greater than 25,000. We use this small glossary to make the code run faster, but you may want to try it with the full list of cities.
#
# First, we need to load the glossary in ETK.
# We're using the default tokenizer to tokenize the strings. Besides, we set `ngrams` to zero to let the program choose the best ngram number automatically.

# %%
my_glossary_extractor = GlossaryExtractor(glossary=city_list, extractor_name='tutorial_glossary', 
                                          tokenizer=etk.default_tokenizer, ngrams=0,
                                          case_sensitive=False)

# %% [markdown]
# Now we are going to use the glossary to extract from the `Home city` column all the strings that match names in geonames. This method will allow us to extract the geonames city name from cells that may contain extraneous information.
#
#
# To run the glossary extractor over all cells containing `Home city` we use a JSON path that selects these cells across all tables.
# Our list of extractions has the names of cities that we know appear in geonames. Often, different cities in the world have the same name (e.g., Paris, France and Paris, Texas). To get the latitude and longitude, we need to identify the correct city. We know all the cities are in Italy, so we can easily filter.

# %%
hit_count = 0
etk.parser = jex.parse
cities_doc = etk.create_document(city_dataset)
for one_row in extracted_rows:
    doc = etk.create_document(one_row)
    city = doc.select_segments('City')
    extractions = doc.extract(my_glossary_extractor, city[0])
    if extractions:
        path = '$."' + extractions[0].value + '"[?(@.country == "Italy")]'
        city_info = cities_doc.select_segments(path)
        if city_info:
            hit_count+=1
            for key in city_info[0].value:
                one_row['city' + key]= city_info[0].value[key]
print('There\'re', hit_count, 'hits for city_list.\n')
print('Final result sample:\n')
print(json.dumps(extracted_rows[0], indent=2))
# Out:
# There're 143 hits for city_list.
#
# Final result sample:
#
# {
#   "Team": "Atalanta",
#   "City": "Bergamo",
#   "Stadium": "Stadio Atleti Azzurri d'Italia",
#   "Capacity": "7004213000000000000\u2660 21,300",
#   "provenances": [
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     },
#     {
#       "@id": 0,
#       "@type": "extraction_provenance_record",
#       "method": "tutorial_glossary",
#       "confidence": 1.0,
#       "origin_record": {
#         "path": "City",
#         "start_char": 0,
#         "end_char": 7
#       }
#     }
#   ],
#   "citypopulation": 114162,
#   "citystate": "Lombardia",
#   "citycountry": "Italy",
#   "citylatitude": "45.69601",
#   "citylongitude": "9.66721"
# }
