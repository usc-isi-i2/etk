# %% [markdown]
# # Excel Extractor
#
# ETK's Excel Extractor is a cell-based extractor for extracting data from compatible spreadsheets.
#
# ## Souce spreadsheet
#
# The example spreadsheet file named `alabama.xml` and it has a sheet named `16tbl08al`, in which row 1 to row 5 and row 60 to row 62 are metadata, 6A to M59 is a table (which has row and colume headers). For this example, I'm going to extract data from C7 to M33 (see the picture attached below).
#
# ![screenshot.png](screenshot.png)

# %% [markdown]
# ## Define where and how to extract data
#
# Excel Extractor will scan cell-by-cell within a region that you specified and fill variables that you defined. In this particular example, I want to extract value of all cells in region (C7, M33) and I defined a variable called `value`. Its value will be extracted from a cell located at `$col, $row` where `$col` and `$row` means current row id and column id that the scanner is at. The return here is a list object which has one variable defined named `value`.

# %%
import pprint
from etk.extractors.excel_extractor import ExcelExtractor
ee = ExcelExtractor()
variables = {
    'value': '$col,$row'
}
raw_extractions = ee.extract('alabama.xls', '16tbl08al', ['C,7', 'M,33'], variables)
pprint.pprint(raw_extractions)
# Out:
# [{'value': 73},
#  {'value': 1},
#  {'value': 12},
#  {'value': ''},
#  {'value': 8},
#  {'value': 52},
#  {'value': 429},
#  {'value': 146},
#  {'value': 233},
#  {'value': 50},
#  {'value': 127},
#  {'value': 1},
#  {'value': 5},
#  {'value': ''},
#  {'value': 23},
#  {'value': 98},
#  {'value': 613},
#  {'value': 229},
#  {'value': 342},
#  {'value': 42},
#  {'value': 0},
#  {'value': 0},
#  {'value': 0},
#  {'value': ''},
#  {'value': 0},
#  {'value': 0},
#  {'value': 37},
#  {'value': 20},
#  {'value': 14},
#  {'value': 3},
#  {'value': 394},
#  {'value': 1},
#  {'value': 17},
#  {'value': ''},
#  {'value': 9},
#  {'value': 367},
#  {'value': 867},
#  {'value': 261},
#  {'value': 501},
#  {'value': 105},
#  {'value': 23},
#  {'value': 0},
#  {'value': 7},
#  {'value': ''},
#  {'value': 5},
#  {'value': 11},
#  {'value': 319},
#  {'value': 137},
#  {'value': 181},
#  {'value': 1},
#  {'value': 151},
#  {'value': 0},
#  {'value': 10},
#  {'value': ''},
#  {'value': 3},
#  {'value': 138},
#  {'value': 592},
#  {'value': 247},
#  {'value': 295},
#  {'value': 50},
#  {'value': 88},
#  {'value': 4},
#  {'value': 22},
#  {'value': ''},
#  {'value': 7},
#  {'value': 55},
#  {'value': 677},
#  {'value': 223},
#  {'value': 408},
#  {'value': 46},
#  {'value': 135},
#  {'value': 1},
#  {'value': 20},
#  {'value': ''},
#  {'value': 7},
#  {'value': 107},
#  {'value': 480},
#  {'value': 149},
#  {'value': 255},
#  {'value': 76},
#  {'value': 46},
#  {'value': 1},
#  {'value': 9},
#  {'value': ''},
#  {'value': 2},
#  {'value': 34},
#  {'value': 205},
#  {'value': 71},
#  {'value': 106},
#  {'value': 28},
#  {'value': 33},
#  {'value': 0},
#  {'value': 2},
#  {'value': ''},
#  {'value': 2},
#  {'value': 29},
#  {'value': 139},
#  {'value': 73},
#  {'value': 55},
#  {'value': 11},
#  {'value': 13},
#  {'value': 0},
#  {'value': 1},
#  {'value': ''},
#  {'value': 1},
#  {'value': 11},
#  {'value': 86},
#  {'value': 34},
#  {'value': 44},
#  {'value': 8},
#  {'value': 114},
#  {'value': 4},
#  {'value': 18},
#  {'value': ''},
#  {'value': 7},
#  {'value': 85},
#  {'value': 616},
#  {'value': 179},
#  {'value': 395},
#  {'value': 42},
#  {'value': 693},
#  {'value': 5},
#  {'value': 48},
#  {'value': ''},
#  {'value': 173},
#  {'value': 467},
#  {'value': 2659},
#  {'value': 1589},
#  {'value': 919},
#  {'value': 151},
#  {'value': 30},
#  {'value': 1},
#  {'value': 2},
#  {'value': ''},
#  {'value': 0},
#  {'value': 27},
#  {'value': 285},
#  {'value': 54},
#  {'value': 190},
#  {'value': 41},
#  {'value': 70},
#  {'value': 0},
#  {'value': 7},
#  {'value': ''},
#  {'value': 6},
#  {'value': 57},
#  {'value': 326},
#  {'value': 105},
#  {'value': 189},
#  {'value': 32},
#  {'value': 443},
#  {'value': 10},
#  {'value': 21},
#  {'value': ''},
#  {'value': 18},
#  {'value': 394},
#  {'value': 1296},
#  {'value': 389},
#  {'value': 807},
#  {'value': 100},
#  {'value': 120},
#  {'value': 0},
#  {'value': 29},
#  {'value': ''},
#  {'value': 9},
#  {'value': 82},
#  {'value': 829},
#  {'value': 202},
#  {'value': 565},
#  {'value': 62},
#  {'value': 51},
#  {'value': 2},
#  {'value': 5},
#  {'value': ''},
#  {'value': 9},
#  {'value': 35},
#  {'value': 224},
#  {'value': 96},
#  {'value': 108},
#  {'value': 20},
#  {'value': 341},
#  {'value': 2},
#  {'value': 44},
#  {'value': ''},
#  {'value': 39},
#  {'value': 256},
#  {'value': 2257},
#  {'value': 576},
#  {'value': 1474},
#  {'value': 207},
#  {'value': 151},
#  {'value': 9},
#  {'value': 13},
#  {'value': ''},
#  {'value': 26},
#  {'value': 103},
#  {'value': 2149},
#  {'value': 612},
#  {'value': 1299},
#  {'value': 238},
#  {'value': 117},
#  {'value': 1},
#  {'value': 4},
#  {'value': ''},
#  {'value': 8},
#  {'value': 104},
#  {'value': 360},
#  {'value': 121},
#  {'value': 198},
#  {'value': 41},
#  {'value': 71},
#  {'value': 0},
#  {'value': 10},
#  {'value': ''},
#  {'value': 2},
#  {'value': 59},
#  {'value': 373},
#  {'value': 192},
#  {'value': 165},
#  {'value': 16},
#  {'value': 66},
#  {'value': 2},
#  {'value': 20},
#  {'value': ''},
#  {'value': 5},
#  {'value': 39},
#  {'value': 372},
#  {'value': 124},
#  {'value': 206},
#  {'value': 42},
#  {'value': 111},
#  {'value': 3},
#  {'value': 25},
#  {'value': ''},
#  {'value': 8},
#  {'value': 75},
#  {'value': 886},
#  {'value': 251},
#  {'value': 537},
#  {'value': 98},
#  {'value': 236},
#  {'value': 0},
#  {'value': 20},
#  {'value': ''},
#  {'value': 4},
#  {'value': 212},
#  {'value': 541},
#  {'value': 214},
#  {'value': 303},
#  {'value': 24},
#  {'value': 185},
#  {'value': 1},
#  {'value': 6},
#  {'value': ''},
#  {'value': 22},
#  {'value': 156},
#  {'value': 1234},
#  {'value': 387},
#  {'value': 726},
#  {'value': 121}]

# %% [markdown]
# Excel Extractor allows you to define multiple variables. This is useful if you want to extract the data from other cells which are associated with current cell. In this example, I also need colume header (category) and country name of every cell in the region. It supports fixed coordinate like `($B,$1)` (which means the cell at colume B row 1) or using `+` and `-` to caculate relative coordinate like `($B-1,$row+1)` (which means the cell colume A and row id is current row+1).

# %%
variables = {
    'value': '$col,$row',
    'country': '$B,$row',
    'category': '$col,$6'
}
raw_extractions = ee.extract('alabama.xls', '16tbl08al', ['C,7', 'M,33'], variables)
pprint.pprint(raw_extractions)
# Out:
# [{'category': 'Violent\ncrime', 'country': 'Autauga', 'value': 73},
#  {'category': 'Violent\ncrime', 'country': 'Autauga', 'value': 73},
#  {'category': 'Violent\ncrime', 'country': 'Autauga', 'value': 73},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Autauga',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Autauga',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Autauga',
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Autauga',
#   'value': 12},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Autauga',
#   'value': 12},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Autauga',
#   'value': 12},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Autauga', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Autauga', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Autauga', 'value': ''},
#  {'category': 'Robbery', 'country': 'Autauga', 'value': 8},
#  {'category': 'Robbery', 'country': 'Autauga', 'value': 8},
#  {'category': 'Robbery', 'country': 'Autauga', 'value': 8},
#  {'category': 'Aggravated\nassault', 'country': 'Autauga', 'value': 52},
#  {'category': 'Aggravated\nassault', 'country': 'Autauga', 'value': 52},
#  {'category': 'Aggravated\nassault', 'country': 'Autauga', 'value': 52},
#  {'category': 'Property\ncrime', 'country': 'Autauga', 'value': 429},
#  {'category': 'Property\ncrime', 'country': 'Autauga', 'value': 429},
#  {'category': 'Property\ncrime', 'country': 'Autauga', 'value': 429},
#  {'category': 'Burglary', 'country': 'Autauga', 'value': 146},
#  {'category': 'Burglary', 'country': 'Autauga', 'value': 146},
#  {'category': 'Burglary', 'country': 'Autauga', 'value': 146},
#  {'category': 'Larceny-\ntheft', 'country': 'Autauga', 'value': 233},
#  {'category': 'Larceny-\ntheft', 'country': 'Autauga', 'value': 233},
#  {'category': 'Larceny-\ntheft', 'country': 'Autauga', 'value': 233},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Autauga', 'value': 50},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Autauga', 'value': 50},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Autauga', 'value': 50},
#  {'category': 'Violent\ncrime', 'country': 'Baldwin', 'value': 127},
#  {'category': 'Violent\ncrime', 'country': 'Baldwin', 'value': 127},
#  {'category': 'Violent\ncrime', 'country': 'Baldwin', 'value': 127},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Baldwin',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Baldwin',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Baldwin',
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Baldwin', 'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Baldwin', 'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Baldwin', 'value': 5},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Baldwin', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Baldwin', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Baldwin', 'value': ''},
#  {'category': 'Robbery', 'country': 'Baldwin', 'value': 23},
#  {'category': 'Robbery', 'country': 'Baldwin', 'value': 23},
#  {'category': 'Robbery', 'country': 'Baldwin', 'value': 23},
#  {'category': 'Aggravated\nassault', 'country': 'Baldwin', 'value': 98},
#  {'category': 'Aggravated\nassault', 'country': 'Baldwin', 'value': 98},
#  {'category': 'Aggravated\nassault', 'country': 'Baldwin', 'value': 98},
#  {'category': 'Property\ncrime', 'country': 'Baldwin', 'value': 613},
#  {'category': 'Property\ncrime', 'country': 'Baldwin', 'value': 613},
#  {'category': 'Property\ncrime', 'country': 'Baldwin', 'value': 613},
#  {'category': 'Burglary', 'country': 'Baldwin', 'value': 229},
#  {'category': 'Burglary', 'country': 'Baldwin', 'value': 229},
#  {'category': 'Burglary', 'country': 'Baldwin', 'value': 229},
#  {'category': 'Larceny-\ntheft', 'country': 'Baldwin', 'value': 342},
#  {'category': 'Larceny-\ntheft', 'country': 'Baldwin', 'value': 342},
#  {'category': 'Larceny-\ntheft', 'country': 'Baldwin', 'value': 342},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Baldwin', 'value': 42},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Baldwin', 'value': 42},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Baldwin', 'value': 42},
#  {'category': 'Violent\ncrime', 'country': 'Bibb', 'value': 0},
#  {'category': 'Violent\ncrime', 'country': 'Bibb', 'value': 0},
#  {'category': 'Violent\ncrime', 'country': 'Bibb', 'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Bibb',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Bibb',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Bibb',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Bibb', 'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Bibb', 'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Bibb', 'value': 0},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Bibb', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Bibb', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Bibb', 'value': ''},
#  {'category': 'Robbery', 'country': 'Bibb', 'value': 0},
#  {'category': 'Robbery', 'country': 'Bibb', 'value': 0},
#  {'category': 'Robbery', 'country': 'Bibb', 'value': 0},
#  {'category': 'Aggravated\nassault', 'country': 'Bibb', 'value': 0},
#  {'category': 'Aggravated\nassault', 'country': 'Bibb', 'value': 0},
#  {'category': 'Aggravated\nassault', 'country': 'Bibb', 'value': 0},
#  {'category': 'Property\ncrime', 'country': 'Bibb', 'value': 37},
#  {'category': 'Property\ncrime', 'country': 'Bibb', 'value': 37},
#  {'category': 'Property\ncrime', 'country': 'Bibb', 'value': 37},
#  {'category': 'Burglary', 'country': 'Bibb', 'value': 20},
#  {'category': 'Burglary', 'country': 'Bibb', 'value': 20},
#  {'category': 'Burglary', 'country': 'Bibb', 'value': 20},
#  {'category': 'Larceny-\ntheft', 'country': 'Bibb', 'value': 14},
#  {'category': 'Larceny-\ntheft', 'country': 'Bibb', 'value': 14},
#  {'category': 'Larceny-\ntheft', 'country': 'Bibb', 'value': 14},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Bibb', 'value': 3},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Bibb', 'value': 3},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Bibb', 'value': 3},
#  {'category': 'Violent\ncrime', 'country': 'Blount', 'value': 394},
#  {'category': 'Violent\ncrime', 'country': 'Blount', 'value': 394},
#  {'category': 'Violent\ncrime', 'country': 'Blount', 'value': 394},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Blount',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Blount',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Blount',
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Blount', 'value': 17},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Blount', 'value': 17},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Blount', 'value': 17},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Blount', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Blount', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Blount', 'value': ''},
#  {'category': 'Robbery', 'country': 'Blount', 'value': 9},
#  {'category': 'Robbery', 'country': 'Blount', 'value': 9},
#  {'category': 'Robbery', 'country': 'Blount', 'value': 9},
#  {'category': 'Aggravated\nassault', 'country': 'Blount', 'value': 367},
#  {'category': 'Aggravated\nassault', 'country': 'Blount', 'value': 367},
#  {'category': 'Aggravated\nassault', 'country': 'Blount', 'value': 367},
#  {'category': 'Property\ncrime', 'country': 'Blount', 'value': 867},
#  {'category': 'Property\ncrime', 'country': 'Blount', 'value': 867},
#  {'category': 'Property\ncrime', 'country': 'Blount', 'value': 867},
#  {'category': 'Burglary', 'country': 'Blount', 'value': 261},
#  {'category': 'Burglary', 'country': 'Blount', 'value': 261},
#  {'category': 'Burglary', 'country': 'Blount', 'value': 261},
#  {'category': 'Larceny-\ntheft', 'country': 'Blount', 'value': 501},
#  {'category': 'Larceny-\ntheft', 'country': 'Blount', 'value': 501},
#  {'category': 'Larceny-\ntheft', 'country': 'Blount', 'value': 501},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Blount', 'value': 105},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Blount', 'value': 105},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Blount', 'value': 105},
#  {'category': 'Violent\ncrime', 'country': 'Calhoun', 'value': 23},
#  {'category': 'Violent\ncrime', 'country': 'Calhoun', 'value': 23},
#  {'category': 'Violent\ncrime', 'country': 'Calhoun', 'value': 23},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Calhoun',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Calhoun',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Calhoun',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Calhoun', 'value': 7},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Calhoun', 'value': 7},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Calhoun', 'value': 7},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Calhoun', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Calhoun', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Calhoun', 'value': ''},
#  {'category': 'Robbery', 'country': 'Calhoun', 'value': 5},
#  {'category': 'Robbery', 'country': 'Calhoun', 'value': 5},
#  {'category': 'Robbery', 'country': 'Calhoun', 'value': 5},
#  {'category': 'Aggravated\nassault', 'country': 'Calhoun', 'value': 11},
#  {'category': 'Aggravated\nassault', 'country': 'Calhoun', 'value': 11},
#  {'category': 'Aggravated\nassault', 'country': 'Calhoun', 'value': 11},
#  {'category': 'Property\ncrime', 'country': 'Calhoun', 'value': 319},
#  {'category': 'Property\ncrime', 'country': 'Calhoun', 'value': 319},
#  {'category': 'Property\ncrime', 'country': 'Calhoun', 'value': 319},
#  {'category': 'Burglary', 'country': 'Calhoun', 'value': 137},
#  {'category': 'Burglary', 'country': 'Calhoun', 'value': 137},
#  {'category': 'Burglary', 'country': 'Calhoun', 'value': 137},
#  {'category': 'Larceny-\ntheft', 'country': 'Calhoun', 'value': 181},
#  {'category': 'Larceny-\ntheft', 'country': 'Calhoun', 'value': 181},
#  {'category': 'Larceny-\ntheft', 'country': 'Calhoun', 'value': 181},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Calhoun', 'value': 1},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Calhoun', 'value': 1},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Calhoun', 'value': 1},
#  {'category': 'Violent\ncrime', 'country': 'Chilton', 'value': 151},
#  {'category': 'Violent\ncrime', 'country': 'Chilton', 'value': 151},
#  {'category': 'Violent\ncrime', 'country': 'Chilton', 'value': 151},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Chilton',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Chilton',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Chilton',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Chilton',
#   'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Chilton',
#   'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Chilton',
#   'value': 10},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Chilton', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Chilton', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Chilton', 'value': ''},
#  {'category': 'Robbery', 'country': 'Chilton', 'value': 3},
#  {'category': 'Robbery', 'country': 'Chilton', 'value': 3},
#  {'category': 'Robbery', 'country': 'Chilton', 'value': 3},
#  {'category': 'Aggravated\nassault', 'country': 'Chilton', 'value': 138},
#  {'category': 'Aggravated\nassault', 'country': 'Chilton', 'value': 138},
#  {'category': 'Aggravated\nassault', 'country': 'Chilton', 'value': 138},
#  {'category': 'Property\ncrime', 'country': 'Chilton', 'value': 592},
#  {'category': 'Property\ncrime', 'country': 'Chilton', 'value': 592},
#  {'category': 'Property\ncrime', 'country': 'Chilton', 'value': 592},
#  {'category': 'Burglary', 'country': 'Chilton', 'value': 247},
#  {'category': 'Burglary', 'country': 'Chilton', 'value': 247},
#  {'category': 'Burglary', 'country': 'Chilton', 'value': 247},
#  {'category': 'Larceny-\ntheft', 'country': 'Chilton', 'value': 295},
#  {'category': 'Larceny-\ntheft', 'country': 'Chilton', 'value': 295},
#  {'category': 'Larceny-\ntheft', 'country': 'Chilton', 'value': 295},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Chilton', 'value': 50},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Chilton', 'value': 50},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Chilton', 'value': 50},
#  {'category': 'Violent\ncrime', 'country': 'Elmore', 'value': 88},
#  {'category': 'Violent\ncrime', 'country': 'Elmore', 'value': 88},
#  {'category': 'Violent\ncrime', 'country': 'Elmore', 'value': 88},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Elmore',
#   'value': 4},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Elmore',
#   'value': 4},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Elmore',
#   'value': 4},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Elmore', 'value': 22},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Elmore', 'value': 22},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Elmore', 'value': 22},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Elmore', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Elmore', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Elmore', 'value': ''},
#  {'category': 'Robbery', 'country': 'Elmore', 'value': 7},
#  {'category': 'Robbery', 'country': 'Elmore', 'value': 7},
#  {'category': 'Robbery', 'country': 'Elmore', 'value': 7},
#  {'category': 'Aggravated\nassault', 'country': 'Elmore', 'value': 55},
#  {'category': 'Aggravated\nassault', 'country': 'Elmore', 'value': 55},
#  {'category': 'Aggravated\nassault', 'country': 'Elmore', 'value': 55},
#  {'category': 'Property\ncrime', 'country': 'Elmore', 'value': 677},
#  {'category': 'Property\ncrime', 'country': 'Elmore', 'value': 677},
#  {'category': 'Property\ncrime', 'country': 'Elmore', 'value': 677},
#  {'category': 'Burglary', 'country': 'Elmore', 'value': 223},
#  {'category': 'Burglary', 'country': 'Elmore', 'value': 223},
#  {'category': 'Burglary', 'country': 'Elmore', 'value': 223},
#  {'category': 'Larceny-\ntheft', 'country': 'Elmore', 'value': 408},
#  {'category': 'Larceny-\ntheft', 'country': 'Elmore', 'value': 408},
#  {'category': 'Larceny-\ntheft', 'country': 'Elmore', 'value': 408},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Elmore', 'value': 46},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Elmore', 'value': 46},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Elmore', 'value': 46},
#  {'category': 'Violent\ncrime', 'country': 'Etowah', 'value': 135},
#  {'category': 'Violent\ncrime', 'country': 'Etowah', 'value': 135},
#  {'category': 'Violent\ncrime', 'country': 'Etowah', 'value': 135},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Etowah',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Etowah',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Etowah',
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Etowah', 'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Etowah', 'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Etowah', 'value': 20},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Etowah', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Etowah', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Etowah', 'value': ''},
#  {'category': 'Robbery', 'country': 'Etowah', 'value': 7},
#  {'category': 'Robbery', 'country': 'Etowah', 'value': 7},
#  {'category': 'Robbery', 'country': 'Etowah', 'value': 7},
#  {'category': 'Aggravated\nassault', 'country': 'Etowah', 'value': 107},
#  {'category': 'Aggravated\nassault', 'country': 'Etowah', 'value': 107},
#  {'category': 'Aggravated\nassault', 'country': 'Etowah', 'value': 107},
#  {'category': 'Property\ncrime', 'country': 'Etowah', 'value': 480},
#  {'category': 'Property\ncrime', 'country': 'Etowah', 'value': 480},
#  {'category': 'Property\ncrime', 'country': 'Etowah', 'value': 480},
#  {'category': 'Burglary', 'country': 'Etowah', 'value': 149},
#  {'category': 'Burglary', 'country': 'Etowah', 'value': 149},
#  {'category': 'Burglary', 'country': 'Etowah', 'value': 149},
#  {'category': 'Larceny-\ntheft', 'country': 'Etowah', 'value': 255},
#  {'category': 'Larceny-\ntheft', 'country': 'Etowah', 'value': 255},
#  {'category': 'Larceny-\ntheft', 'country': 'Etowah', 'value': 255},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Etowah', 'value': 76},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Etowah', 'value': 76},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Etowah', 'value': 76},
#  {'category': 'Violent\ncrime', 'country': 'Geneva', 'value': 46},
#  {'category': 'Violent\ncrime', 'country': 'Geneva', 'value': 46},
#  {'category': 'Violent\ncrime', 'country': 'Geneva', 'value': 46},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Geneva',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Geneva',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Geneva',
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Geneva', 'value': 9},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Geneva', 'value': 9},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Geneva', 'value': 9},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Geneva', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Geneva', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Geneva', 'value': ''},
#  {'category': 'Robbery', 'country': 'Geneva', 'value': 2},
#  {'category': 'Robbery', 'country': 'Geneva', 'value': 2},
#  {'category': 'Robbery', 'country': 'Geneva', 'value': 2},
#  {'category': 'Aggravated\nassault', 'country': 'Geneva', 'value': 34},
#  {'category': 'Aggravated\nassault', 'country': 'Geneva', 'value': 34},
#  {'category': 'Aggravated\nassault', 'country': 'Geneva', 'value': 34},
#  {'category': 'Property\ncrime', 'country': 'Geneva', 'value': 205},
#  {'category': 'Property\ncrime', 'country': 'Geneva', 'value': 205},
#  {'category': 'Property\ncrime', 'country': 'Geneva', 'value': 205},
#  {'category': 'Burglary', 'country': 'Geneva', 'value': 71},
#  {'category': 'Burglary', 'country': 'Geneva', 'value': 71},
#  {'category': 'Burglary', 'country': 'Geneva', 'value': 71},
#  {'category': 'Larceny-\ntheft', 'country': 'Geneva', 'value': 106},
#  {'category': 'Larceny-\ntheft', 'country': 'Geneva', 'value': 106},
#  {'category': 'Larceny-\ntheft', 'country': 'Geneva', 'value': 106},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Geneva', 'value': 28},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Geneva', 'value': 28},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Geneva', 'value': 28},
#  {'category': 'Violent\ncrime', 'country': 'Hale', 'value': 33},
#  {'category': 'Violent\ncrime', 'country': 'Hale', 'value': 33},
#  {'category': 'Violent\ncrime', 'country': 'Hale', 'value': 33},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Hale',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Hale',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Hale',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Hale', 'value': 2},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Hale', 'value': 2},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Hale', 'value': 2},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Hale', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Hale', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Hale', 'value': ''},
#  {'category': 'Robbery', 'country': 'Hale', 'value': 2},
#  {'category': 'Robbery', 'country': 'Hale', 'value': 2},
#  {'category': 'Robbery', 'country': 'Hale', 'value': 2},
#  {'category': 'Aggravated\nassault', 'country': 'Hale', 'value': 29},
#  {'category': 'Aggravated\nassault', 'country': 'Hale', 'value': 29},
#  {'category': 'Aggravated\nassault', 'country': 'Hale', 'value': 29},
#  {'category': 'Property\ncrime', 'country': 'Hale', 'value': 139},
#  {'category': 'Property\ncrime', 'country': 'Hale', 'value': 139},
#  {'category': 'Property\ncrime', 'country': 'Hale', 'value': 139},
#  {'category': 'Burglary', 'country': 'Hale', 'value': 73},
#  {'category': 'Burglary', 'country': 'Hale', 'value': 73},
#  {'category': 'Burglary', 'country': 'Hale', 'value': 73},
#  {'category': 'Larceny-\ntheft', 'country': 'Hale', 'value': 55},
#  {'category': 'Larceny-\ntheft', 'country': 'Hale', 'value': 55},
#  {'category': 'Larceny-\ntheft', 'country': 'Hale', 'value': 55},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Hale', 'value': 11},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Hale', 'value': 11},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Hale', 'value': 11},
#  {'category': 'Violent\ncrime', 'country': 'Henry', 'value': 13},
#  {'category': 'Violent\ncrime', 'country': 'Henry', 'value': 13},
#  {'category': 'Violent\ncrime', 'country': 'Henry', 'value': 13},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Henry',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Henry',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Henry',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Henry', 'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Henry', 'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Henry', 'value': 1},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Henry', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Henry', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Henry', 'value': ''},
#  {'category': 'Robbery', 'country': 'Henry', 'value': 1},
#  {'category': 'Robbery', 'country': 'Henry', 'value': 1},
#  {'category': 'Robbery', 'country': 'Henry', 'value': 1},
#  {'category': 'Aggravated\nassault', 'country': 'Henry', 'value': 11},
#  {'category': 'Aggravated\nassault', 'country': 'Henry', 'value': 11},
#  {'category': 'Aggravated\nassault', 'country': 'Henry', 'value': 11},
#  {'category': 'Property\ncrime', 'country': 'Henry', 'value': 86},
#  {'category': 'Property\ncrime', 'country': 'Henry', 'value': 86},
#  {'category': 'Property\ncrime', 'country': 'Henry', 'value': 86},
#  {'category': 'Burglary', 'country': 'Henry', 'value': 34},
#  {'category': 'Burglary', 'country': 'Henry', 'value': 34},
#  {'category': 'Burglary', 'country': 'Henry', 'value': 34},
#  {'category': 'Larceny-\ntheft', 'country': 'Henry', 'value': 44},
#  {'category': 'Larceny-\ntheft', 'country': 'Henry', 'value': 44},
#  {'category': 'Larceny-\ntheft', 'country': 'Henry', 'value': 44},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Henry', 'value': 8},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Henry', 'value': 8},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Henry', 'value': 8},
#  {'category': 'Violent\ncrime', 'country': 'Houston', 'value': 114},
#  {'category': 'Violent\ncrime', 'country': 'Houston', 'value': 114},
#  {'category': 'Violent\ncrime', 'country': 'Houston', 'value': 114},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Houston',
#   'value': 4},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Houston',
#   'value': 4},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Houston',
#   'value': 4},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Houston',
#   'value': 18},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Houston',
#   'value': 18},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Houston',
#   'value': 18},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Houston', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Houston', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Houston', 'value': ''},
#  {'category': 'Robbery', 'country': 'Houston', 'value': 7},
#  {'category': 'Robbery', 'country': 'Houston', 'value': 7},
#  {'category': 'Robbery', 'country': 'Houston', 'value': 7},
#  {'category': 'Aggravated\nassault', 'country': 'Houston', 'value': 85},
#  {'category': 'Aggravated\nassault', 'country': 'Houston', 'value': 85},
#  {'category': 'Aggravated\nassault', 'country': 'Houston', 'value': 85},
#  {'category': 'Property\ncrime', 'country': 'Houston', 'value': 616},
#  {'category': 'Property\ncrime', 'country': 'Houston', 'value': 616},
#  {'category': 'Property\ncrime', 'country': 'Houston', 'value': 616},
#  {'category': 'Burglary', 'country': 'Houston', 'value': 179},
#  {'category': 'Burglary', 'country': 'Houston', 'value': 179},
#  {'category': 'Burglary', 'country': 'Houston', 'value': 179},
#  {'category': 'Larceny-\ntheft', 'country': 'Houston', 'value': 395},
#  {'category': 'Larceny-\ntheft', 'country': 'Houston', 'value': 395},
#  {'category': 'Larceny-\ntheft', 'country': 'Houston', 'value': 395},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Houston', 'value': 42},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Houston', 'value': 42},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Houston', 'value': 42},
#  {'category': 'Violent\ncrime', 'country': 'Jefferson', 'value': 693},
#  {'category': 'Violent\ncrime', 'country': 'Jefferson', 'value': 693},
#  {'category': 'Violent\ncrime', 'country': 'Jefferson', 'value': 693},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Jefferson',
#   'value': 5},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Jefferson',
#   'value': 5},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Jefferson',
#   'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Jefferson',
#   'value': 48},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Jefferson',
#   'value': 48},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Jefferson',
#   'value': 48},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Jefferson',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Jefferson',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Jefferson',
#   'value': ''},
#  {'category': 'Robbery', 'country': 'Jefferson', 'value': 173},
#  {'category': 'Robbery', 'country': 'Jefferson', 'value': 173},
#  {'category': 'Robbery', 'country': 'Jefferson', 'value': 173},
#  {'category': 'Aggravated\nassault', 'country': 'Jefferson', 'value': 467},
#  {'category': 'Aggravated\nassault', 'country': 'Jefferson', 'value': 467},
#  {'category': 'Aggravated\nassault', 'country': 'Jefferson', 'value': 467},
#  {'category': 'Property\ncrime', 'country': 'Jefferson', 'value': 2659},
#  {'category': 'Property\ncrime', 'country': 'Jefferson', 'value': 2659},
#  {'category': 'Property\ncrime', 'country': 'Jefferson', 'value': 2659},
#  {'category': 'Burglary', 'country': 'Jefferson', 'value': 1589},
#  {'category': 'Burglary', 'country': 'Jefferson', 'value': 1589},
#  {'category': 'Burglary', 'country': 'Jefferson', 'value': 1589},
#  {'category': 'Larceny-\ntheft', 'country': 'Jefferson', 'value': 919},
#  {'category': 'Larceny-\ntheft', 'country': 'Jefferson', 'value': 919},
#  {'category': 'Larceny-\ntheft', 'country': 'Jefferson', 'value': 919},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Jefferson', 'value': 151},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Jefferson', 'value': 151},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Jefferson', 'value': 151},
#  {'category': 'Violent\ncrime', 'country': 'Lauderdale', 'value': 30},
#  {'category': 'Violent\ncrime', 'country': 'Lauderdale', 'value': 30},
#  {'category': 'Violent\ncrime', 'country': 'Lauderdale', 'value': 30},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lauderdale',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lauderdale',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lauderdale',
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Lauderdale',
#   'value': 2},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Lauderdale',
#   'value': 2},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Lauderdale',
#   'value': 2},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Lauderdale',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Lauderdale',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Lauderdale',
#   'value': ''},
#  {'category': 'Robbery', 'country': 'Lauderdale', 'value': 0},
#  {'category': 'Robbery', 'country': 'Lauderdale', 'value': 0},
#  {'category': 'Robbery', 'country': 'Lauderdale', 'value': 0},
#  {'category': 'Aggravated\nassault', 'country': 'Lauderdale', 'value': 27},
#  {'category': 'Aggravated\nassault', 'country': 'Lauderdale', 'value': 27},
#  {'category': 'Aggravated\nassault', 'country': 'Lauderdale', 'value': 27},
#  {'category': 'Property\ncrime', 'country': 'Lauderdale', 'value': 285},
#  {'category': 'Property\ncrime', 'country': 'Lauderdale', 'value': 285},
#  {'category': 'Property\ncrime', 'country': 'Lauderdale', 'value': 285},
#  {'category': 'Burglary', 'country': 'Lauderdale', 'value': 54},
#  {'category': 'Burglary', 'country': 'Lauderdale', 'value': 54},
#  {'category': 'Burglary', 'country': 'Lauderdale', 'value': 54},
#  {'category': 'Larceny-\ntheft', 'country': 'Lauderdale', 'value': 190},
#  {'category': 'Larceny-\ntheft', 'country': 'Lauderdale', 'value': 190},
#  {'category': 'Larceny-\ntheft', 'country': 'Lauderdale', 'value': 190},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lauderdale', 'value': 41},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lauderdale', 'value': 41},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lauderdale', 'value': 41},
#  {'category': 'Violent\ncrime', 'country': 'Lawrence', 'value': 70},
#  {'category': 'Violent\ncrime', 'country': 'Lawrence', 'value': 70},
#  {'category': 'Violent\ncrime', 'country': 'Lawrence', 'value': 70},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lawrence',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lawrence',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lawrence',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Lawrence',
#   'value': 7},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Lawrence',
#   'value': 7},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Lawrence',
#   'value': 7},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Lawrence',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Lawrence',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Lawrence',
#   'value': ''},
#  {'category': 'Robbery', 'country': 'Lawrence', 'value': 6},
#  {'category': 'Robbery', 'country': 'Lawrence', 'value': 6},
#  {'category': 'Robbery', 'country': 'Lawrence', 'value': 6},
#  {'category': 'Aggravated\nassault', 'country': 'Lawrence', 'value': 57},
#  {'category': 'Aggravated\nassault', 'country': 'Lawrence', 'value': 57},
#  {'category': 'Aggravated\nassault', 'country': 'Lawrence', 'value': 57},
#  {'category': 'Property\ncrime', 'country': 'Lawrence', 'value': 326},
#  {'category': 'Property\ncrime', 'country': 'Lawrence', 'value': 326},
#  {'category': 'Property\ncrime', 'country': 'Lawrence', 'value': 326},
#  {'category': 'Burglary', 'country': 'Lawrence', 'value': 105},
#  {'category': 'Burglary', 'country': 'Lawrence', 'value': 105},
#  {'category': 'Burglary', 'country': 'Lawrence', 'value': 105},
#  {'category': 'Larceny-\ntheft', 'country': 'Lawrence', 'value': 189},
#  {'category': 'Larceny-\ntheft', 'country': 'Lawrence', 'value': 189},
#  {'category': 'Larceny-\ntheft', 'country': 'Lawrence', 'value': 189},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lawrence', 'value': 32},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lawrence', 'value': 32},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lawrence', 'value': 32},
#  {'category': 'Violent\ncrime', 'country': 'Lee', 'value': 443},
#  {'category': 'Violent\ncrime', 'country': 'Lee', 'value': 443},
#  {'category': 'Violent\ncrime', 'country': 'Lee', 'value': 443},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lee',
#   'value': 10},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lee',
#   'value': 10},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lee',
#   'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Lee', 'value': 21},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Lee', 'value': 21},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Lee', 'value': 21},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Lee', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Lee', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Lee', 'value': ''},
#  {'category': 'Robbery', 'country': 'Lee', 'value': 18},
#  {'category': 'Robbery', 'country': 'Lee', 'value': 18},
#  {'category': 'Robbery', 'country': 'Lee', 'value': 18},
#  {'category': 'Aggravated\nassault', 'country': 'Lee', 'value': 394},
#  {'category': 'Aggravated\nassault', 'country': 'Lee', 'value': 394},
#  {'category': 'Aggravated\nassault', 'country': 'Lee', 'value': 394},
#  {'category': 'Property\ncrime', 'country': 'Lee', 'value': 1296},
#  {'category': 'Property\ncrime', 'country': 'Lee', 'value': 1296},
#  {'category': 'Property\ncrime', 'country': 'Lee', 'value': 1296},
#  {'category': 'Burglary', 'country': 'Lee', 'value': 389},
#  {'category': 'Burglary', 'country': 'Lee', 'value': 389},
#  {'category': 'Burglary', 'country': 'Lee', 'value': 389},
#  {'category': 'Larceny-\ntheft', 'country': 'Lee', 'value': 807},
#  {'category': 'Larceny-\ntheft', 'country': 'Lee', 'value': 807},
#  {'category': 'Larceny-\ntheft', 'country': 'Lee', 'value': 807},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lee', 'value': 100},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lee', 'value': 100},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lee', 'value': 100},
#  {'category': 'Violent\ncrime', 'country': 'Limestone', 'value': 120},
#  {'category': 'Violent\ncrime', 'country': 'Limestone', 'value': 120},
#  {'category': 'Violent\ncrime', 'country': 'Limestone', 'value': 120},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Limestone',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Limestone',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Limestone',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Limestone',
#   'value': 29},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Limestone',
#   'value': 29},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Limestone',
#   'value': 29},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Limestone',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Limestone',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Limestone',
#   'value': ''},
#  {'category': 'Robbery', 'country': 'Limestone', 'value': 9},
#  {'category': 'Robbery', 'country': 'Limestone', 'value': 9},
#  {'category': 'Robbery', 'country': 'Limestone', 'value': 9},
#  {'category': 'Aggravated\nassault', 'country': 'Limestone', 'value': 82},
#  {'category': 'Aggravated\nassault', 'country': 'Limestone', 'value': 82},
#  {'category': 'Aggravated\nassault', 'country': 'Limestone', 'value': 82},
#  {'category': 'Property\ncrime', 'country': 'Limestone', 'value': 829},
#  {'category': 'Property\ncrime', 'country': 'Limestone', 'value': 829},
#  {'category': 'Property\ncrime', 'country': 'Limestone', 'value': 829},
#  {'category': 'Burglary', 'country': 'Limestone', 'value': 202},
#  {'category': 'Burglary', 'country': 'Limestone', 'value': 202},
#  {'category': 'Burglary', 'country': 'Limestone', 'value': 202},
#  {'category': 'Larceny-\ntheft', 'country': 'Limestone', 'value': 565},
#  {'category': 'Larceny-\ntheft', 'country': 'Limestone', 'value': 565},
#  {'category': 'Larceny-\ntheft', 'country': 'Limestone', 'value': 565},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Limestone', 'value': 62},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Limestone', 'value': 62},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Limestone', 'value': 62},
#  {'category': 'Violent\ncrime', 'country': 'Lowndes', 'value': 51},
#  {'category': 'Violent\ncrime', 'country': 'Lowndes', 'value': 51},
#  {'category': 'Violent\ncrime', 'country': 'Lowndes', 'value': 51},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lowndes',
#   'value': 2},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lowndes',
#   'value': 2},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Lowndes',
#   'value': 2},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Lowndes', 'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Lowndes', 'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Lowndes', 'value': 5},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Lowndes', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Lowndes', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Lowndes', 'value': ''},
#  {'category': 'Robbery', 'country': 'Lowndes', 'value': 9},
#  {'category': 'Robbery', 'country': 'Lowndes', 'value': 9},
#  {'category': 'Robbery', 'country': 'Lowndes', 'value': 9},
#  {'category': 'Aggravated\nassault', 'country': 'Lowndes', 'value': 35},
#  {'category': 'Aggravated\nassault', 'country': 'Lowndes', 'value': 35},
#  {'category': 'Aggravated\nassault', 'country': 'Lowndes', 'value': 35},
#  {'category': 'Property\ncrime', 'country': 'Lowndes', 'value': 224},
#  {'category': 'Property\ncrime', 'country': 'Lowndes', 'value': 224},
#  {'category': 'Property\ncrime', 'country': 'Lowndes', 'value': 224},
#  {'category': 'Burglary', 'country': 'Lowndes', 'value': 96},
#  {'category': 'Burglary', 'country': 'Lowndes', 'value': 96},
#  {'category': 'Burglary', 'country': 'Lowndes', 'value': 96},
#  {'category': 'Larceny-\ntheft', 'country': 'Lowndes', 'value': 108},
#  {'category': 'Larceny-\ntheft', 'country': 'Lowndes', 'value': 108},
#  {'category': 'Larceny-\ntheft', 'country': 'Lowndes', 'value': 108},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lowndes', 'value': 20},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lowndes', 'value': 20},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Lowndes', 'value': 20},
#  {'category': 'Violent\ncrime', 'country': 'Madison', 'value': 341},
#  {'category': 'Violent\ncrime', 'country': 'Madison', 'value': 341},
#  {'category': 'Violent\ncrime', 'country': 'Madison', 'value': 341},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Madison',
#   'value': 2},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Madison',
#   'value': 2},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Madison',
#   'value': 2},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Madison',
#   'value': 44},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Madison',
#   'value': 44},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Madison',
#   'value': 44},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Madison', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Madison', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Madison', 'value': ''},
#  {'category': 'Robbery', 'country': 'Madison', 'value': 39},
#  {'category': 'Robbery', 'country': 'Madison', 'value': 39},
#  {'category': 'Robbery', 'country': 'Madison', 'value': 39},
#  {'category': 'Aggravated\nassault', 'country': 'Madison', 'value': 256},
#  {'category': 'Aggravated\nassault', 'country': 'Madison', 'value': 256},
#  {'category': 'Aggravated\nassault', 'country': 'Madison', 'value': 256},
#  {'category': 'Property\ncrime', 'country': 'Madison', 'value': 2257},
#  {'category': 'Property\ncrime', 'country': 'Madison', 'value': 2257},
#  {'category': 'Property\ncrime', 'country': 'Madison', 'value': 2257},
#  {'category': 'Burglary', 'country': 'Madison', 'value': 576},
#  {'category': 'Burglary', 'country': 'Madison', 'value': 576},
#  {'category': 'Burglary', 'country': 'Madison', 'value': 576},
#  {'category': 'Larceny-\ntheft', 'country': 'Madison', 'value': 1474},
#  {'category': 'Larceny-\ntheft', 'country': 'Madison', 'value': 1474},
#  {'category': 'Larceny-\ntheft', 'country': 'Madison', 'value': 1474},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Madison', 'value': 207},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Madison', 'value': 207},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Madison', 'value': 207},
#  {'category': 'Violent\ncrime', 'country': 'Mobile', 'value': 151},
#  {'category': 'Violent\ncrime', 'country': 'Mobile', 'value': 151},
#  {'category': 'Violent\ncrime', 'country': 'Mobile', 'value': 151},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Mobile',
#   'value': 9},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Mobile',
#   'value': 9},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Mobile',
#   'value': 9},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Mobile', 'value': 13},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Mobile', 'value': 13},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Mobile', 'value': 13},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Mobile', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Mobile', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Mobile', 'value': ''},
#  {'category': 'Robbery', 'country': 'Mobile', 'value': 26},
#  {'category': 'Robbery', 'country': 'Mobile', 'value': 26},
#  {'category': 'Robbery', 'country': 'Mobile', 'value': 26},
#  {'category': 'Aggravated\nassault', 'country': 'Mobile', 'value': 103},
#  {'category': 'Aggravated\nassault', 'country': 'Mobile', 'value': 103},
#  {'category': 'Aggravated\nassault', 'country': 'Mobile', 'value': 103},
#  {'category': 'Property\ncrime', 'country': 'Mobile', 'value': 2149},
#  {'category': 'Property\ncrime', 'country': 'Mobile', 'value': 2149},
#  {'category': 'Property\ncrime', 'country': 'Mobile', 'value': 2149},
#  {'category': 'Burglary', 'country': 'Mobile', 'value': 612},
#  {'category': 'Burglary', 'country': 'Mobile', 'value': 612},
#  {'category': 'Burglary', 'country': 'Mobile', 'value': 612},
#  {'category': 'Larceny-\ntheft', 'country': 'Mobile', 'value': 1299},
#  {'category': 'Larceny-\ntheft', 'country': 'Mobile', 'value': 1299},
#  {'category': 'Larceny-\ntheft', 'country': 'Mobile', 'value': 1299},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Mobile', 'value': 238},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Mobile', 'value': 238},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Mobile', 'value': 238},
#  {'category': 'Violent\ncrime', 'country': 'Montgomery', 'value': 117},
#  {'category': 'Violent\ncrime', 'country': 'Montgomery', 'value': 117},
#  {'category': 'Violent\ncrime', 'country': 'Montgomery', 'value': 117},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Montgomery',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Montgomery',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Montgomery',
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Montgomery',
#   'value': 4},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Montgomery',
#   'value': 4},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Montgomery',
#   'value': 4},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Montgomery',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Montgomery',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Montgomery',
#   'value': ''},
#  {'category': 'Robbery', 'country': 'Montgomery', 'value': 8},
#  {'category': 'Robbery', 'country': 'Montgomery', 'value': 8},
#  {'category': 'Robbery', 'country': 'Montgomery', 'value': 8},
#  {'category': 'Aggravated\nassault', 'country': 'Montgomery', 'value': 104},
#  {'category': 'Aggravated\nassault', 'country': 'Montgomery', 'value': 104},
#  {'category': 'Aggravated\nassault', 'country': 'Montgomery', 'value': 104},
#  {'category': 'Property\ncrime', 'country': 'Montgomery', 'value': 360},
#  {'category': 'Property\ncrime', 'country': 'Montgomery', 'value': 360},
#  {'category': 'Property\ncrime', 'country': 'Montgomery', 'value': 360},
#  {'category': 'Burglary', 'country': 'Montgomery', 'value': 121},
#  {'category': 'Burglary', 'country': 'Montgomery', 'value': 121},
#  {'category': 'Burglary', 'country': 'Montgomery', 'value': 121},
#  {'category': 'Larceny-\ntheft', 'country': 'Montgomery', 'value': 198},
#  {'category': 'Larceny-\ntheft', 'country': 'Montgomery', 'value': 198},
#  {'category': 'Larceny-\ntheft', 'country': 'Montgomery', 'value': 198},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Montgomery', 'value': 41},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Montgomery', 'value': 41},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Montgomery', 'value': 41},
#  {'category': 'Violent\ncrime', 'country': 'Morgan', 'value': 71},
#  {'category': 'Violent\ncrime', 'country': 'Morgan', 'value': 71},
#  {'category': 'Violent\ncrime', 'country': 'Morgan', 'value': 71},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Morgan',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Morgan',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Morgan',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Morgan', 'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Morgan', 'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Morgan', 'value': 10},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Morgan', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Morgan', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Morgan', 'value': ''},
#  {'category': 'Robbery', 'country': 'Morgan', 'value': 2},
#  {'category': 'Robbery', 'country': 'Morgan', 'value': 2},
#  {'category': 'Robbery', 'country': 'Morgan', 'value': 2},
#  {'category': 'Aggravated\nassault', 'country': 'Morgan', 'value': 59},
#  {'category': 'Aggravated\nassault', 'country': 'Morgan', 'value': 59},
#  {'category': 'Aggravated\nassault', 'country': 'Morgan', 'value': 59},
#  {'category': 'Property\ncrime', 'country': 'Morgan', 'value': 373},
#  {'category': 'Property\ncrime', 'country': 'Morgan', 'value': 373},
#  {'category': 'Property\ncrime', 'country': 'Morgan', 'value': 373},
#  {'category': 'Burglary', 'country': 'Morgan', 'value': 192},
#  {'category': 'Burglary', 'country': 'Morgan', 'value': 192},
#  {'category': 'Burglary', 'country': 'Morgan', 'value': 192},
#  {'category': 'Larceny-\ntheft', 'country': 'Morgan', 'value': 165},
#  {'category': 'Larceny-\ntheft', 'country': 'Morgan', 'value': 165},
#  {'category': 'Larceny-\ntheft', 'country': 'Morgan', 'value': 165},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Morgan', 'value': 16},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Morgan', 'value': 16},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Morgan', 'value': 16},
#  {'category': 'Violent\ncrime', 'country': 'Russell', 'value': 66},
#  {'category': 'Violent\ncrime', 'country': 'Russell', 'value': 66},
#  {'category': 'Violent\ncrime', 'country': 'Russell', 'value': 66},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Russell',
#   'value': 2},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Russell',
#   'value': 2},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Russell',
#   'value': 2},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Russell',
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Russell',
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Russell',
#   'value': 20},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Russell', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Russell', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Russell', 'value': ''},
#  {'category': 'Robbery', 'country': 'Russell', 'value': 5},
#  {'category': 'Robbery', 'country': 'Russell', 'value': 5},
#  {'category': 'Robbery', 'country': 'Russell', 'value': 5},
#  {'category': 'Aggravated\nassault', 'country': 'Russell', 'value': 39},
#  {'category': 'Aggravated\nassault', 'country': 'Russell', 'value': 39},
#  {'category': 'Aggravated\nassault', 'country': 'Russell', 'value': 39},
#  {'category': 'Property\ncrime', 'country': 'Russell', 'value': 372},
#  {'category': 'Property\ncrime', 'country': 'Russell', 'value': 372},
#  {'category': 'Property\ncrime', 'country': 'Russell', 'value': 372},
#  {'category': 'Burglary', 'country': 'Russell', 'value': 124},
#  {'category': 'Burglary', 'country': 'Russell', 'value': 124},
#  {'category': 'Burglary', 'country': 'Russell', 'value': 124},
#  {'category': 'Larceny-\ntheft', 'country': 'Russell', 'value': 206},
#  {'category': 'Larceny-\ntheft', 'country': 'Russell', 'value': 206},
#  {'category': 'Larceny-\ntheft', 'country': 'Russell', 'value': 206},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Russell', 'value': 42},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Russell', 'value': 42},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Russell', 'value': 42},
#  {'category': 'Violent\ncrime', 'country': 'Shelby', 'value': 111},
#  {'category': 'Violent\ncrime', 'country': 'Shelby', 'value': 111},
#  {'category': 'Violent\ncrime', 'country': 'Shelby', 'value': 111},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Shelby',
#   'value': 3},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Shelby',
#   'value': 3},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Shelby',
#   'value': 3},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Shelby', 'value': 25},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Shelby', 'value': 25},
#  {'category': 'Rape\n(revised\ndefinition)1', 'country': 'Shelby', 'value': 25},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Shelby', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Shelby', 'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2', 'country': 'Shelby', 'value': ''},
#  {'category': 'Robbery', 'country': 'Shelby', 'value': 8},
#  {'category': 'Robbery', 'country': 'Shelby', 'value': 8},
#  {'category': 'Robbery', 'country': 'Shelby', 'value': 8},
#  {'category': 'Aggravated\nassault', 'country': 'Shelby', 'value': 75},
#  {'category': 'Aggravated\nassault', 'country': 'Shelby', 'value': 75},
#  {'category': 'Aggravated\nassault', 'country': 'Shelby', 'value': 75},
#  {'category': 'Property\ncrime', 'country': 'Shelby', 'value': 886},
#  {'category': 'Property\ncrime', 'country': 'Shelby', 'value': 886},
#  {'category': 'Property\ncrime', 'country': 'Shelby', 'value': 886},
#  {'category': 'Burglary', 'country': 'Shelby', 'value': 251},
#  {'category': 'Burglary', 'country': 'Shelby', 'value': 251},
#  {'category': 'Burglary', 'country': 'Shelby', 'value': 251},
#  {'category': 'Larceny-\ntheft', 'country': 'Shelby', 'value': 537},
#  {'category': 'Larceny-\ntheft', 'country': 'Shelby', 'value': 537},
#  {'category': 'Larceny-\ntheft', 'country': 'Shelby', 'value': 537},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Shelby', 'value': 98},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Shelby', 'value': 98},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Shelby', 'value': 98},
#  {'category': 'Violent\ncrime', 'country': 'St. Clair', 'value': 236},
#  {'category': 'Violent\ncrime', 'country': 'St. Clair', 'value': 236},
#  {'category': 'Violent\ncrime', 'country': 'St. Clair', 'value': 236},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'St. Clair',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'St. Clair',
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'St. Clair',
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'St. Clair',
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'St. Clair',
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'St. Clair',
#   'value': 20},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'St. Clair',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'St. Clair',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'St. Clair',
#   'value': ''},
#  {'category': 'Robbery', 'country': 'St. Clair', 'value': 4},
#  {'category': 'Robbery', 'country': 'St. Clair', 'value': 4},
#  {'category': 'Robbery', 'country': 'St. Clair', 'value': 4},
#  {'category': 'Aggravated\nassault', 'country': 'St. Clair', 'value': 212},
#  {'category': 'Aggravated\nassault', 'country': 'St. Clair', 'value': 212},
#  {'category': 'Aggravated\nassault', 'country': 'St. Clair', 'value': 212},
#  {'category': 'Property\ncrime', 'country': 'St. Clair', 'value': 541},
#  {'category': 'Property\ncrime', 'country': 'St. Clair', 'value': 541},
#  {'category': 'Property\ncrime', 'country': 'St. Clair', 'value': 541},
#  {'category': 'Burglary', 'country': 'St. Clair', 'value': 214},
#  {'category': 'Burglary', 'country': 'St. Clair', 'value': 214},
#  {'category': 'Burglary', 'country': 'St. Clair', 'value': 214},
#  {'category': 'Larceny-\ntheft', 'country': 'St. Clair', 'value': 303},
#  {'category': 'Larceny-\ntheft', 'country': 'St. Clair', 'value': 303},
#  {'category': 'Larceny-\ntheft', 'country': 'St. Clair', 'value': 303},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'St. Clair', 'value': 24},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'St. Clair', 'value': 24},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'St. Clair', 'value': 24},
#  {'category': 'Violent\ncrime', 'country': 'Tuscaloosa', 'value': 185},
#  {'category': 'Violent\ncrime', 'country': 'Tuscaloosa', 'value': 185},
#  {'category': 'Violent\ncrime', 'country': 'Tuscaloosa', 'value': 185},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Tuscaloosa',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Tuscaloosa',
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Tuscaloosa',
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Tuscaloosa',
#   'value': 6},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Tuscaloosa',
#   'value': 6},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Tuscaloosa',
#   'value': 6},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Tuscaloosa',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Tuscaloosa',
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Tuscaloosa',
#   'value': ''},
#  {'category': 'Robbery', 'country': 'Tuscaloosa', 'value': 22},
#  {'category': 'Robbery', 'country': 'Tuscaloosa', 'value': 22},
#  {'category': 'Robbery', 'country': 'Tuscaloosa', 'value': 22},
#  {'category': 'Aggravated\nassault', 'country': 'Tuscaloosa', 'value': 156},
#  {'category': 'Aggravated\nassault', 'country': 'Tuscaloosa', 'value': 156},
#  {'category': 'Aggravated\nassault', 'country': 'Tuscaloosa', 'value': 156},
#  {'category': 'Property\ncrime', 'country': 'Tuscaloosa', 'value': 1234},
#  {'category': 'Property\ncrime', 'country': 'Tuscaloosa', 'value': 1234},
#  {'category': 'Property\ncrime', 'country': 'Tuscaloosa', 'value': 1234},
#  {'category': 'Burglary', 'country': 'Tuscaloosa', 'value': 387},
#  {'category': 'Burglary', 'country': 'Tuscaloosa', 'value': 387},
#  {'category': 'Burglary', 'country': 'Tuscaloosa', 'value': 387},
#  {'category': 'Larceny-\ntheft', 'country': 'Tuscaloosa', 'value': 726},
#  {'category': 'Larceny-\ntheft', 'country': 'Tuscaloosa', 'value': 726},
#  {'category': 'Larceny-\ntheft', 'country': 'Tuscaloosa', 'value': 726},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Tuscaloosa', 'value': 121},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Tuscaloosa', 'value': 121},
#  {'category': 'Motor\nvehicle\ntheft', 'country': 'Tuscaloosa', 'value': 121}]

# %% [markdown]
# Besides the coordinate, the value of variables can also be a builtin variable (it only supports `$row` and `$col` right now). This can be used for getting provenance of extractions. Both row and colume id here are presented in numeric form.

# %%
variables = {
    'value': '$col,$row',
    'country': '$B,$row',
    'category': '$col,$6',
    'from_row': '$row',
    'from_col': '$col'
}
raw_extractions = ee.extract('alabama.xls', '16tbl08al', ['C,7', 'M,33'], variables)
pprint.pprint(raw_extractions)
# Out:
# [{'category': 'Violent\ncrime',
#   'country': 'Autauga',
#   'from_col': 2,
#   'from_row': 6,
#   'value': 73},
#  {'category': 'Violent\ncrime',
#   'country': 'Autauga',
#   'from_col': 2,
#   'from_row': 6,
#   'value': 73},
#  {'category': 'Violent\ncrime',
#   'country': 'Autauga',
#   'from_col': 2,
#   'from_row': 6,
#   'value': 73},
#  {'category': 'Violent\ncrime',
#   'country': 'Autauga',
#   'from_col': 2,
#   'from_row': 6,
#   'value': 73},
#  {'category': 'Violent\ncrime',
#   'country': 'Autauga',
#   'from_col': 2,
#   'from_row': 6,
#   'value': 73},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Autauga',
#   'from_col': 3,
#   'from_row': 6,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Autauga',
#   'from_col': 3,
#   'from_row': 6,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Autauga',
#   'from_col': 3,
#   'from_row': 6,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Autauga',
#   'from_col': 3,
#   'from_row': 6,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Autauga',
#   'from_col': 3,
#   'from_row': 6,
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Autauga',
#   'from_col': 4,
#   'from_row': 6,
#   'value': 12},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Autauga',
#   'from_col': 4,
#   'from_row': 6,
#   'value': 12},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Autauga',
#   'from_col': 4,
#   'from_row': 6,
#   'value': 12},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Autauga',
#   'from_col': 4,
#   'from_row': 6,
#   'value': 12},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Autauga',
#   'from_col': 4,
#   'from_row': 6,
#   'value': 12},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Autauga',
#   'from_col': 5,
#   'from_row': 6,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Autauga',
#   'from_col': 5,
#   'from_row': 6,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Autauga',
#   'from_col': 5,
#   'from_row': 6,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Autauga',
#   'from_col': 5,
#   'from_row': 6,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Autauga',
#   'from_col': 5,
#   'from_row': 6,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Autauga',
#   'from_col': 6,
#   'from_row': 6,
#   'value': 8},
#  {'category': 'Robbery',
#   'country': 'Autauga',
#   'from_col': 6,
#   'from_row': 6,
#   'value': 8},
#  {'category': 'Robbery',
#   'country': 'Autauga',
#   'from_col': 6,
#   'from_row': 6,
#   'value': 8},
#  {'category': 'Robbery',
#   'country': 'Autauga',
#   'from_col': 6,
#   'from_row': 6,
#   'value': 8},
#  {'category': 'Robbery',
#   'country': 'Autauga',
#   'from_col': 6,
#   'from_row': 6,
#   'value': 8},
#  {'category': 'Aggravated\nassault',
#   'country': 'Autauga',
#   'from_col': 7,
#   'from_row': 6,
#   'value': 52},
#  {'category': 'Aggravated\nassault',
#   'country': 'Autauga',
#   'from_col': 7,
#   'from_row': 6,
#   'value': 52},
#  {'category': 'Aggravated\nassault',
#   'country': 'Autauga',
#   'from_col': 7,
#   'from_row': 6,
#   'value': 52},
#  {'category': 'Aggravated\nassault',
#   'country': 'Autauga',
#   'from_col': 7,
#   'from_row': 6,
#   'value': 52},
#  {'category': 'Aggravated\nassault',
#   'country': 'Autauga',
#   'from_col': 7,
#   'from_row': 6,
#   'value': 52},
#  {'category': 'Property\ncrime',
#   'country': 'Autauga',
#   'from_col': 8,
#   'from_row': 6,
#   'value': 429},
#  {'category': 'Property\ncrime',
#   'country': 'Autauga',
#   'from_col': 8,
#   'from_row': 6,
#   'value': 429},
#  {'category': 'Property\ncrime',
#   'country': 'Autauga',
#   'from_col': 8,
#   'from_row': 6,
#   'value': 429},
#  {'category': 'Property\ncrime',
#   'country': 'Autauga',
#   'from_col': 8,
#   'from_row': 6,
#   'value': 429},
#  {'category': 'Property\ncrime',
#   'country': 'Autauga',
#   'from_col': 8,
#   'from_row': 6,
#   'value': 429},
#  {'category': 'Burglary',
#   'country': 'Autauga',
#   'from_col': 9,
#   'from_row': 6,
#   'value': 146},
#  {'category': 'Burglary',
#   'country': 'Autauga',
#   'from_col': 9,
#   'from_row': 6,
#   'value': 146},
#  {'category': 'Burglary',
#   'country': 'Autauga',
#   'from_col': 9,
#   'from_row': 6,
#   'value': 146},
#  {'category': 'Burglary',
#   'country': 'Autauga',
#   'from_col': 9,
#   'from_row': 6,
#   'value': 146},
#  {'category': 'Burglary',
#   'country': 'Autauga',
#   'from_col': 9,
#   'from_row': 6,
#   'value': 146},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Autauga',
#   'from_col': 10,
#   'from_row': 6,
#   'value': 233},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Autauga',
#   'from_col': 10,
#   'from_row': 6,
#   'value': 233},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Autauga',
#   'from_col': 10,
#   'from_row': 6,
#   'value': 233},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Autauga',
#   'from_col': 10,
#   'from_row': 6,
#   'value': 233},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Autauga',
#   'from_col': 10,
#   'from_row': 6,
#   'value': 233},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Autauga',
#   'from_col': 11,
#   'from_row': 6,
#   'value': 50},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Autauga',
#   'from_col': 11,
#   'from_row': 6,
#   'value': 50},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Autauga',
#   'from_col': 11,
#   'from_row': 6,
#   'value': 50},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Autauga',
#   'from_col': 11,
#   'from_row': 6,
#   'value': 50},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Autauga',
#   'from_col': 11,
#   'from_row': 6,
#   'value': 50},
#  {'category': 'Violent\ncrime',
#   'country': 'Baldwin',
#   'from_col': 2,
#   'from_row': 7,
#   'value': 127},
#  {'category': 'Violent\ncrime',
#   'country': 'Baldwin',
#   'from_col': 2,
#   'from_row': 7,
#   'value': 127},
#  {'category': 'Violent\ncrime',
#   'country': 'Baldwin',
#   'from_col': 2,
#   'from_row': 7,
#   'value': 127},
#  {'category': 'Violent\ncrime',
#   'country': 'Baldwin',
#   'from_col': 2,
#   'from_row': 7,
#   'value': 127},
#  {'category': 'Violent\ncrime',
#   'country': 'Baldwin',
#   'from_col': 2,
#   'from_row': 7,
#   'value': 127},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Baldwin',
#   'from_col': 3,
#   'from_row': 7,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Baldwin',
#   'from_col': 3,
#   'from_row': 7,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Baldwin',
#   'from_col': 3,
#   'from_row': 7,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Baldwin',
#   'from_col': 3,
#   'from_row': 7,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Baldwin',
#   'from_col': 3,
#   'from_row': 7,
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Baldwin',
#   'from_col': 4,
#   'from_row': 7,
#   'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Baldwin',
#   'from_col': 4,
#   'from_row': 7,
#   'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Baldwin',
#   'from_col': 4,
#   'from_row': 7,
#   'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Baldwin',
#   'from_col': 4,
#   'from_row': 7,
#   'value': 5},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Baldwin',
#   'from_col': 4,
#   'from_row': 7,
#   'value': 5},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Baldwin',
#   'from_col': 5,
#   'from_row': 7,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Baldwin',
#   'from_col': 5,
#   'from_row': 7,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Baldwin',
#   'from_col': 5,
#   'from_row': 7,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Baldwin',
#   'from_col': 5,
#   'from_row': 7,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Baldwin',
#   'from_col': 5,
#   'from_row': 7,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Baldwin',
#   'from_col': 6,
#   'from_row': 7,
#   'value': 23},
#  {'category': 'Robbery',
#   'country': 'Baldwin',
#   'from_col': 6,
#   'from_row': 7,
#   'value': 23},
#  {'category': 'Robbery',
#   'country': 'Baldwin',
#   'from_col': 6,
#   'from_row': 7,
#   'value': 23},
#  {'category': 'Robbery',
#   'country': 'Baldwin',
#   'from_col': 6,
#   'from_row': 7,
#   'value': 23},
#  {'category': 'Robbery',
#   'country': 'Baldwin',
#   'from_col': 6,
#   'from_row': 7,
#   'value': 23},
#  {'category': 'Aggravated\nassault',
#   'country': 'Baldwin',
#   'from_col': 7,
#   'from_row': 7,
#   'value': 98},
#  {'category': 'Aggravated\nassault',
#   'country': 'Baldwin',
#   'from_col': 7,
#   'from_row': 7,
#   'value': 98},
#  {'category': 'Aggravated\nassault',
#   'country': 'Baldwin',
#   'from_col': 7,
#   'from_row': 7,
#   'value': 98},
#  {'category': 'Aggravated\nassault',
#   'country': 'Baldwin',
#   'from_col': 7,
#   'from_row': 7,
#   'value': 98},
#  {'category': 'Aggravated\nassault',
#   'country': 'Baldwin',
#   'from_col': 7,
#   'from_row': 7,
#   'value': 98},
#  {'category': 'Property\ncrime',
#   'country': 'Baldwin',
#   'from_col': 8,
#   'from_row': 7,
#   'value': 613},
#  {'category': 'Property\ncrime',
#   'country': 'Baldwin',
#   'from_col': 8,
#   'from_row': 7,
#   'value': 613},
#  {'category': 'Property\ncrime',
#   'country': 'Baldwin',
#   'from_col': 8,
#   'from_row': 7,
#   'value': 613},
#  {'category': 'Property\ncrime',
#   'country': 'Baldwin',
#   'from_col': 8,
#   'from_row': 7,
#   'value': 613},
#  {'category': 'Property\ncrime',
#   'country': 'Baldwin',
#   'from_col': 8,
#   'from_row': 7,
#   'value': 613},
#  {'category': 'Burglary',
#   'country': 'Baldwin',
#   'from_col': 9,
#   'from_row': 7,
#   'value': 229},
#  {'category': 'Burglary',
#   'country': 'Baldwin',
#   'from_col': 9,
#   'from_row': 7,
#   'value': 229},
#  {'category': 'Burglary',
#   'country': 'Baldwin',
#   'from_col': 9,
#   'from_row': 7,
#   'value': 229},
#  {'category': 'Burglary',
#   'country': 'Baldwin',
#   'from_col': 9,
#   'from_row': 7,
#   'value': 229},
#  {'category': 'Burglary',
#   'country': 'Baldwin',
#   'from_col': 9,
#   'from_row': 7,
#   'value': 229},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Baldwin',
#   'from_col': 10,
#   'from_row': 7,
#   'value': 342},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Baldwin',
#   'from_col': 10,
#   'from_row': 7,
#   'value': 342},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Baldwin',
#   'from_col': 10,
#   'from_row': 7,
#   'value': 342},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Baldwin',
#   'from_col': 10,
#   'from_row': 7,
#   'value': 342},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Baldwin',
#   'from_col': 10,
#   'from_row': 7,
#   'value': 342},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Baldwin',
#   'from_col': 11,
#   'from_row': 7,
#   'value': 42},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Baldwin',
#   'from_col': 11,
#   'from_row': 7,
#   'value': 42},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Baldwin',
#   'from_col': 11,
#   'from_row': 7,
#   'value': 42},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Baldwin',
#   'from_col': 11,
#   'from_row': 7,
#   'value': 42},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Baldwin',
#   'from_col': 11,
#   'from_row': 7,
#   'value': 42},
#  {'category': 'Violent\ncrime',
#   'country': 'Bibb',
#   'from_col': 2,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Violent\ncrime',
#   'country': 'Bibb',
#   'from_col': 2,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Violent\ncrime',
#   'country': 'Bibb',
#   'from_col': 2,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Violent\ncrime',
#   'country': 'Bibb',
#   'from_col': 2,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Violent\ncrime',
#   'country': 'Bibb',
#   'from_col': 2,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Bibb',
#   'from_col': 3,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Bibb',
#   'from_col': 3,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Bibb',
#   'from_col': 3,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Bibb',
#   'from_col': 3,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Bibb',
#   'from_col': 3,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Bibb',
#   'from_col': 4,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Bibb',
#   'from_col': 4,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Bibb',
#   'from_col': 4,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Bibb',
#   'from_col': 4,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Bibb',
#   'from_col': 4,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Bibb',
#   'from_col': 5,
#   'from_row': 8,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Bibb',
#   'from_col': 5,
#   'from_row': 8,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Bibb',
#   'from_col': 5,
#   'from_row': 8,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Bibb',
#   'from_col': 5,
#   'from_row': 8,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Bibb',
#   'from_col': 5,
#   'from_row': 8,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Bibb',
#   'from_col': 6,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Robbery',
#   'country': 'Bibb',
#   'from_col': 6,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Robbery',
#   'country': 'Bibb',
#   'from_col': 6,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Robbery',
#   'country': 'Bibb',
#   'from_col': 6,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Robbery',
#   'country': 'Bibb',
#   'from_col': 6,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Aggravated\nassault',
#   'country': 'Bibb',
#   'from_col': 7,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Aggravated\nassault',
#   'country': 'Bibb',
#   'from_col': 7,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Aggravated\nassault',
#   'country': 'Bibb',
#   'from_col': 7,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Aggravated\nassault',
#   'country': 'Bibb',
#   'from_col': 7,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Aggravated\nassault',
#   'country': 'Bibb',
#   'from_col': 7,
#   'from_row': 8,
#   'value': 0},
#  {'category': 'Property\ncrime',
#   'country': 'Bibb',
#   'from_col': 8,
#   'from_row': 8,
#   'value': 37},
#  {'category': 'Property\ncrime',
#   'country': 'Bibb',
#   'from_col': 8,
#   'from_row': 8,
#   'value': 37},
#  {'category': 'Property\ncrime',
#   'country': 'Bibb',
#   'from_col': 8,
#   'from_row': 8,
#   'value': 37},
#  {'category': 'Property\ncrime',
#   'country': 'Bibb',
#   'from_col': 8,
#   'from_row': 8,
#   'value': 37},
#  {'category': 'Property\ncrime',
#   'country': 'Bibb',
#   'from_col': 8,
#   'from_row': 8,
#   'value': 37},
#  {'category': 'Burglary',
#   'country': 'Bibb',
#   'from_col': 9,
#   'from_row': 8,
#   'value': 20},
#  {'category': 'Burglary',
#   'country': 'Bibb',
#   'from_col': 9,
#   'from_row': 8,
#   'value': 20},
#  {'category': 'Burglary',
#   'country': 'Bibb',
#   'from_col': 9,
#   'from_row': 8,
#   'value': 20},
#  {'category': 'Burglary',
#   'country': 'Bibb',
#   'from_col': 9,
#   'from_row': 8,
#   'value': 20},
#  {'category': 'Burglary',
#   'country': 'Bibb',
#   'from_col': 9,
#   'from_row': 8,
#   'value': 20},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Bibb',
#   'from_col': 10,
#   'from_row': 8,
#   'value': 14},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Bibb',
#   'from_col': 10,
#   'from_row': 8,
#   'value': 14},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Bibb',
#   'from_col': 10,
#   'from_row': 8,
#   'value': 14},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Bibb',
#   'from_col': 10,
#   'from_row': 8,
#   'value': 14},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Bibb',
#   'from_col': 10,
#   'from_row': 8,
#   'value': 14},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Bibb',
#   'from_col': 11,
#   'from_row': 8,
#   'value': 3},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Bibb',
#   'from_col': 11,
#   'from_row': 8,
#   'value': 3},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Bibb',
#   'from_col': 11,
#   'from_row': 8,
#   'value': 3},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Bibb',
#   'from_col': 11,
#   'from_row': 8,
#   'value': 3},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Bibb',
#   'from_col': 11,
#   'from_row': 8,
#   'value': 3},
#  {'category': 'Violent\ncrime',
#   'country': 'Blount',
#   'from_col': 2,
#   'from_row': 9,
#   'value': 394},
#  {'category': 'Violent\ncrime',
#   'country': 'Blount',
#   'from_col': 2,
#   'from_row': 9,
#   'value': 394},
#  {'category': 'Violent\ncrime',
#   'country': 'Blount',
#   'from_col': 2,
#   'from_row': 9,
#   'value': 394},
#  {'category': 'Violent\ncrime',
#   'country': 'Blount',
#   'from_col': 2,
#   'from_row': 9,
#   'value': 394},
#  {'category': 'Violent\ncrime',
#   'country': 'Blount',
#   'from_col': 2,
#   'from_row': 9,
#   'value': 394},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Blount',
#   'from_col': 3,
#   'from_row': 9,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Blount',
#   'from_col': 3,
#   'from_row': 9,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Blount',
#   'from_col': 3,
#   'from_row': 9,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Blount',
#   'from_col': 3,
#   'from_row': 9,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Blount',
#   'from_col': 3,
#   'from_row': 9,
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Blount',
#   'from_col': 4,
#   'from_row': 9,
#   'value': 17},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Blount',
#   'from_col': 4,
#   'from_row': 9,
#   'value': 17},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Blount',
#   'from_col': 4,
#   'from_row': 9,
#   'value': 17},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Blount',
#   'from_col': 4,
#   'from_row': 9,
#   'value': 17},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Blount',
#   'from_col': 4,
#   'from_row': 9,
#   'value': 17},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Blount',
#   'from_col': 5,
#   'from_row': 9,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Blount',
#   'from_col': 5,
#   'from_row': 9,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Blount',
#   'from_col': 5,
#   'from_row': 9,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Blount',
#   'from_col': 5,
#   'from_row': 9,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Blount',
#   'from_col': 5,
#   'from_row': 9,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Blount',
#   'from_col': 6,
#   'from_row': 9,
#   'value': 9},
#  {'category': 'Robbery',
#   'country': 'Blount',
#   'from_col': 6,
#   'from_row': 9,
#   'value': 9},
#  {'category': 'Robbery',
#   'country': 'Blount',
#   'from_col': 6,
#   'from_row': 9,
#   'value': 9},
#  {'category': 'Robbery',
#   'country': 'Blount',
#   'from_col': 6,
#   'from_row': 9,
#   'value': 9},
#  {'category': 'Robbery',
#   'country': 'Blount',
#   'from_col': 6,
#   'from_row': 9,
#   'value': 9},
#  {'category': 'Aggravated\nassault',
#   'country': 'Blount',
#   'from_col': 7,
#   'from_row': 9,
#   'value': 367},
#  {'category': 'Aggravated\nassault',
#   'country': 'Blount',
#   'from_col': 7,
#   'from_row': 9,
#   'value': 367},
#  {'category': 'Aggravated\nassault',
#   'country': 'Blount',
#   'from_col': 7,
#   'from_row': 9,
#   'value': 367},
#  {'category': 'Aggravated\nassault',
#   'country': 'Blount',
#   'from_col': 7,
#   'from_row': 9,
#   'value': 367},
#  {'category': 'Aggravated\nassault',
#   'country': 'Blount',
#   'from_col': 7,
#   'from_row': 9,
#   'value': 367},
#  {'category': 'Property\ncrime',
#   'country': 'Blount',
#   'from_col': 8,
#   'from_row': 9,
#   'value': 867},
#  {'category': 'Property\ncrime',
#   'country': 'Blount',
#   'from_col': 8,
#   'from_row': 9,
#   'value': 867},
#  {'category': 'Property\ncrime',
#   'country': 'Blount',
#   'from_col': 8,
#   'from_row': 9,
#   'value': 867},
#  {'category': 'Property\ncrime',
#   'country': 'Blount',
#   'from_col': 8,
#   'from_row': 9,
#   'value': 867},
#  {'category': 'Property\ncrime',
#   'country': 'Blount',
#   'from_col': 8,
#   'from_row': 9,
#   'value': 867},
#  {'category': 'Burglary',
#   'country': 'Blount',
#   'from_col': 9,
#   'from_row': 9,
#   'value': 261},
#  {'category': 'Burglary',
#   'country': 'Blount',
#   'from_col': 9,
#   'from_row': 9,
#   'value': 261},
#  {'category': 'Burglary',
#   'country': 'Blount',
#   'from_col': 9,
#   'from_row': 9,
#   'value': 261},
#  {'category': 'Burglary',
#   'country': 'Blount',
#   'from_col': 9,
#   'from_row': 9,
#   'value': 261},
#  {'category': 'Burglary',
#   'country': 'Blount',
#   'from_col': 9,
#   'from_row': 9,
#   'value': 261},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Blount',
#   'from_col': 10,
#   'from_row': 9,
#   'value': 501},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Blount',
#   'from_col': 10,
#   'from_row': 9,
#   'value': 501},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Blount',
#   'from_col': 10,
#   'from_row': 9,
#   'value': 501},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Blount',
#   'from_col': 10,
#   'from_row': 9,
#   'value': 501},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Blount',
#   'from_col': 10,
#   'from_row': 9,
#   'value': 501},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Blount',
#   'from_col': 11,
#   'from_row': 9,
#   'value': 105},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Blount',
#   'from_col': 11,
#   'from_row': 9,
#   'value': 105},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Blount',
#   'from_col': 11,
#   'from_row': 9,
#   'value': 105},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Blount',
#   'from_col': 11,
#   'from_row': 9,
#   'value': 105},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Blount',
#   'from_col': 11,
#   'from_row': 9,
#   'value': 105},
#  {'category': 'Violent\ncrime',
#   'country': 'Calhoun',
#   'from_col': 2,
#   'from_row': 10,
#   'value': 23},
#  {'category': 'Violent\ncrime',
#   'country': 'Calhoun',
#   'from_col': 2,
#   'from_row': 10,
#   'value': 23},
#  {'category': 'Violent\ncrime',
#   'country': 'Calhoun',
#   'from_col': 2,
#   'from_row': 10,
#   'value': 23},
#  {'category': 'Violent\ncrime',
#   'country': 'Calhoun',
#   'from_col': 2,
#   'from_row': 10,
#   'value': 23},
#  {'category': 'Violent\ncrime',
#   'country': 'Calhoun',
#   'from_col': 2,
#   'from_row': 10,
#   'value': 23},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Calhoun',
#   'from_col': 3,
#   'from_row': 10,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Calhoun',
#   'from_col': 3,
#   'from_row': 10,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Calhoun',
#   'from_col': 3,
#   'from_row': 10,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Calhoun',
#   'from_col': 3,
#   'from_row': 10,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Calhoun',
#   'from_col': 3,
#   'from_row': 10,
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Calhoun',
#   'from_col': 4,
#   'from_row': 10,
#   'value': 7},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Calhoun',
#   'from_col': 4,
#   'from_row': 10,
#   'value': 7},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Calhoun',
#   'from_col': 4,
#   'from_row': 10,
#   'value': 7},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Calhoun',
#   'from_col': 4,
#   'from_row': 10,
#   'value': 7},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Calhoun',
#   'from_col': 4,
#   'from_row': 10,
#   'value': 7},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Calhoun',
#   'from_col': 5,
#   'from_row': 10,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Calhoun',
#   'from_col': 5,
#   'from_row': 10,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Calhoun',
#   'from_col': 5,
#   'from_row': 10,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Calhoun',
#   'from_col': 5,
#   'from_row': 10,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Calhoun',
#   'from_col': 5,
#   'from_row': 10,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Calhoun',
#   'from_col': 6,
#   'from_row': 10,
#   'value': 5},
#  {'category': 'Robbery',
#   'country': 'Calhoun',
#   'from_col': 6,
#   'from_row': 10,
#   'value': 5},
#  {'category': 'Robbery',
#   'country': 'Calhoun',
#   'from_col': 6,
#   'from_row': 10,
#   'value': 5},
#  {'category': 'Robbery',
#   'country': 'Calhoun',
#   'from_col': 6,
#   'from_row': 10,
#   'value': 5},
#  {'category': 'Robbery',
#   'country': 'Calhoun',
#   'from_col': 6,
#   'from_row': 10,
#   'value': 5},
#  {'category': 'Aggravated\nassault',
#   'country': 'Calhoun',
#   'from_col': 7,
#   'from_row': 10,
#   'value': 11},
#  {'category': 'Aggravated\nassault',
#   'country': 'Calhoun',
#   'from_col': 7,
#   'from_row': 10,
#   'value': 11},
#  {'category': 'Aggravated\nassault',
#   'country': 'Calhoun',
#   'from_col': 7,
#   'from_row': 10,
#   'value': 11},
#  {'category': 'Aggravated\nassault',
#   'country': 'Calhoun',
#   'from_col': 7,
#   'from_row': 10,
#   'value': 11},
#  {'category': 'Aggravated\nassault',
#   'country': 'Calhoun',
#   'from_col': 7,
#   'from_row': 10,
#   'value': 11},
#  {'category': 'Property\ncrime',
#   'country': 'Calhoun',
#   'from_col': 8,
#   'from_row': 10,
#   'value': 319},
#  {'category': 'Property\ncrime',
#   'country': 'Calhoun',
#   'from_col': 8,
#   'from_row': 10,
#   'value': 319},
#  {'category': 'Property\ncrime',
#   'country': 'Calhoun',
#   'from_col': 8,
#   'from_row': 10,
#   'value': 319},
#  {'category': 'Property\ncrime',
#   'country': 'Calhoun',
#   'from_col': 8,
#   'from_row': 10,
#   'value': 319},
#  {'category': 'Property\ncrime',
#   'country': 'Calhoun',
#   'from_col': 8,
#   'from_row': 10,
#   'value': 319},
#  {'category': 'Burglary',
#   'country': 'Calhoun',
#   'from_col': 9,
#   'from_row': 10,
#   'value': 137},
#  {'category': 'Burglary',
#   'country': 'Calhoun',
#   'from_col': 9,
#   'from_row': 10,
#   'value': 137},
#  {'category': 'Burglary',
#   'country': 'Calhoun',
#   'from_col': 9,
#   'from_row': 10,
#   'value': 137},
#  {'category': 'Burglary',
#   'country': 'Calhoun',
#   'from_col': 9,
#   'from_row': 10,
#   'value': 137},
#  {'category': 'Burglary',
#   'country': 'Calhoun',
#   'from_col': 9,
#   'from_row': 10,
#   'value': 137},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Calhoun',
#   'from_col': 10,
#   'from_row': 10,
#   'value': 181},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Calhoun',
#   'from_col': 10,
#   'from_row': 10,
#   'value': 181},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Calhoun',
#   'from_col': 10,
#   'from_row': 10,
#   'value': 181},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Calhoun',
#   'from_col': 10,
#   'from_row': 10,
#   'value': 181},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Calhoun',
#   'from_col': 10,
#   'from_row': 10,
#   'value': 181},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Calhoun',
#   'from_col': 11,
#   'from_row': 10,
#   'value': 1},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Calhoun',
#   'from_col': 11,
#   'from_row': 10,
#   'value': 1},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Calhoun',
#   'from_col': 11,
#   'from_row': 10,
#   'value': 1},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Calhoun',
#   'from_col': 11,
#   'from_row': 10,
#   'value': 1},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Calhoun',
#   'from_col': 11,
#   'from_row': 10,
#   'value': 1},
#  {'category': 'Violent\ncrime',
#   'country': 'Chilton',
#   'from_col': 2,
#   'from_row': 11,
#   'value': 151},
#  {'category': 'Violent\ncrime',
#   'country': 'Chilton',
#   'from_col': 2,
#   'from_row': 11,
#   'value': 151},
#  {'category': 'Violent\ncrime',
#   'country': 'Chilton',
#   'from_col': 2,
#   'from_row': 11,
#   'value': 151},
#  {'category': 'Violent\ncrime',
#   'country': 'Chilton',
#   'from_col': 2,
#   'from_row': 11,
#   'value': 151},
#  {'category': 'Violent\ncrime',
#   'country': 'Chilton',
#   'from_col': 2,
#   'from_row': 11,
#   'value': 151},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Chilton',
#   'from_col': 3,
#   'from_row': 11,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Chilton',
#   'from_col': 3,
#   'from_row': 11,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Chilton',
#   'from_col': 3,
#   'from_row': 11,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Chilton',
#   'from_col': 3,
#   'from_row': 11,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Chilton',
#   'from_col': 3,
#   'from_row': 11,
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Chilton',
#   'from_col': 4,
#   'from_row': 11,
#   'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Chilton',
#   'from_col': 4,
#   'from_row': 11,
#   'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Chilton',
#   'from_col': 4,
#   'from_row': 11,
#   'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Chilton',
#   'from_col': 4,
#   'from_row': 11,
#   'value': 10},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Chilton',
#   'from_col': 4,
#   'from_row': 11,
#   'value': 10},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Chilton',
#   'from_col': 5,
#   'from_row': 11,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Chilton',
#   'from_col': 5,
#   'from_row': 11,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Chilton',
#   'from_col': 5,
#   'from_row': 11,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Chilton',
#   'from_col': 5,
#   'from_row': 11,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Chilton',
#   'from_col': 5,
#   'from_row': 11,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Chilton',
#   'from_col': 6,
#   'from_row': 11,
#   'value': 3},
#  {'category': 'Robbery',
#   'country': 'Chilton',
#   'from_col': 6,
#   'from_row': 11,
#   'value': 3},
#  {'category': 'Robbery',
#   'country': 'Chilton',
#   'from_col': 6,
#   'from_row': 11,
#   'value': 3},
#  {'category': 'Robbery',
#   'country': 'Chilton',
#   'from_col': 6,
#   'from_row': 11,
#   'value': 3},
#  {'category': 'Robbery',
#   'country': 'Chilton',
#   'from_col': 6,
#   'from_row': 11,
#   'value': 3},
#  {'category': 'Aggravated\nassault',
#   'country': 'Chilton',
#   'from_col': 7,
#   'from_row': 11,
#   'value': 138},
#  {'category': 'Aggravated\nassault',
#   'country': 'Chilton',
#   'from_col': 7,
#   'from_row': 11,
#   'value': 138},
#  {'category': 'Aggravated\nassault',
#   'country': 'Chilton',
#   'from_col': 7,
#   'from_row': 11,
#   'value': 138},
#  {'category': 'Aggravated\nassault',
#   'country': 'Chilton',
#   'from_col': 7,
#   'from_row': 11,
#   'value': 138},
#  {'category': 'Aggravated\nassault',
#   'country': 'Chilton',
#   'from_col': 7,
#   'from_row': 11,
#   'value': 138},
#  {'category': 'Property\ncrime',
#   'country': 'Chilton',
#   'from_col': 8,
#   'from_row': 11,
#   'value': 592},
#  {'category': 'Property\ncrime',
#   'country': 'Chilton',
#   'from_col': 8,
#   'from_row': 11,
#   'value': 592},
#  {'category': 'Property\ncrime',
#   'country': 'Chilton',
#   'from_col': 8,
#   'from_row': 11,
#   'value': 592},
#  {'category': 'Property\ncrime',
#   'country': 'Chilton',
#   'from_col': 8,
#   'from_row': 11,
#   'value': 592},
#  {'category': 'Property\ncrime',
#   'country': 'Chilton',
#   'from_col': 8,
#   'from_row': 11,
#   'value': 592},
#  {'category': 'Burglary',
#   'country': 'Chilton',
#   'from_col': 9,
#   'from_row': 11,
#   'value': 247},
#  {'category': 'Burglary',
#   'country': 'Chilton',
#   'from_col': 9,
#   'from_row': 11,
#   'value': 247},
#  {'category': 'Burglary',
#   'country': 'Chilton',
#   'from_col': 9,
#   'from_row': 11,
#   'value': 247},
#  {'category': 'Burglary',
#   'country': 'Chilton',
#   'from_col': 9,
#   'from_row': 11,
#   'value': 247},
#  {'category': 'Burglary',
#   'country': 'Chilton',
#   'from_col': 9,
#   'from_row': 11,
#   'value': 247},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Chilton',
#   'from_col': 10,
#   'from_row': 11,
#   'value': 295},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Chilton',
#   'from_col': 10,
#   'from_row': 11,
#   'value': 295},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Chilton',
#   'from_col': 10,
#   'from_row': 11,
#   'value': 295},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Chilton',
#   'from_col': 10,
#   'from_row': 11,
#   'value': 295},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Chilton',
#   'from_col': 10,
#   'from_row': 11,
#   'value': 295},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Chilton',
#   'from_col': 11,
#   'from_row': 11,
#   'value': 50},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Chilton',
#   'from_col': 11,
#   'from_row': 11,
#   'value': 50},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Chilton',
#   'from_col': 11,
#   'from_row': 11,
#   'value': 50},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Chilton',
#   'from_col': 11,
#   'from_row': 11,
#   'value': 50},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Chilton',
#   'from_col': 11,
#   'from_row': 11,
#   'value': 50},
#  {'category': 'Violent\ncrime',
#   'country': 'Elmore',
#   'from_col': 2,
#   'from_row': 12,
#   'value': 88},
#  {'category': 'Violent\ncrime',
#   'country': 'Elmore',
#   'from_col': 2,
#   'from_row': 12,
#   'value': 88},
#  {'category': 'Violent\ncrime',
#   'country': 'Elmore',
#   'from_col': 2,
#   'from_row': 12,
#   'value': 88},
#  {'category': 'Violent\ncrime',
#   'country': 'Elmore',
#   'from_col': 2,
#   'from_row': 12,
#   'value': 88},
#  {'category': 'Violent\ncrime',
#   'country': 'Elmore',
#   'from_col': 2,
#   'from_row': 12,
#   'value': 88},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Elmore',
#   'from_col': 3,
#   'from_row': 12,
#   'value': 4},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Elmore',
#   'from_col': 3,
#   'from_row': 12,
#   'value': 4},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Elmore',
#   'from_col': 3,
#   'from_row': 12,
#   'value': 4},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Elmore',
#   'from_col': 3,
#   'from_row': 12,
#   'value': 4},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Elmore',
#   'from_col': 3,
#   'from_row': 12,
#   'value': 4},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Elmore',
#   'from_col': 4,
#   'from_row': 12,
#   'value': 22},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Elmore',
#   'from_col': 4,
#   'from_row': 12,
#   'value': 22},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Elmore',
#   'from_col': 4,
#   'from_row': 12,
#   'value': 22},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Elmore',
#   'from_col': 4,
#   'from_row': 12,
#   'value': 22},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Elmore',
#   'from_col': 4,
#   'from_row': 12,
#   'value': 22},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Elmore',
#   'from_col': 5,
#   'from_row': 12,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Elmore',
#   'from_col': 5,
#   'from_row': 12,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Elmore',
#   'from_col': 5,
#   'from_row': 12,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Elmore',
#   'from_col': 5,
#   'from_row': 12,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Elmore',
#   'from_col': 5,
#   'from_row': 12,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Elmore',
#   'from_col': 6,
#   'from_row': 12,
#   'value': 7},
#  {'category': 'Robbery',
#   'country': 'Elmore',
#   'from_col': 6,
#   'from_row': 12,
#   'value': 7},
#  {'category': 'Robbery',
#   'country': 'Elmore',
#   'from_col': 6,
#   'from_row': 12,
#   'value': 7},
#  {'category': 'Robbery',
#   'country': 'Elmore',
#   'from_col': 6,
#   'from_row': 12,
#   'value': 7},
#  {'category': 'Robbery',
#   'country': 'Elmore',
#   'from_col': 6,
#   'from_row': 12,
#   'value': 7},
#  {'category': 'Aggravated\nassault',
#   'country': 'Elmore',
#   'from_col': 7,
#   'from_row': 12,
#   'value': 55},
#  {'category': 'Aggravated\nassault',
#   'country': 'Elmore',
#   'from_col': 7,
#   'from_row': 12,
#   'value': 55},
#  {'category': 'Aggravated\nassault',
#   'country': 'Elmore',
#   'from_col': 7,
#   'from_row': 12,
#   'value': 55},
#  {'category': 'Aggravated\nassault',
#   'country': 'Elmore',
#   'from_col': 7,
#   'from_row': 12,
#   'value': 55},
#  {'category': 'Aggravated\nassault',
#   'country': 'Elmore',
#   'from_col': 7,
#   'from_row': 12,
#   'value': 55},
#  {'category': 'Property\ncrime',
#   'country': 'Elmore',
#   'from_col': 8,
#   'from_row': 12,
#   'value': 677},
#  {'category': 'Property\ncrime',
#   'country': 'Elmore',
#   'from_col': 8,
#   'from_row': 12,
#   'value': 677},
#  {'category': 'Property\ncrime',
#   'country': 'Elmore',
#   'from_col': 8,
#   'from_row': 12,
#   'value': 677},
#  {'category': 'Property\ncrime',
#   'country': 'Elmore',
#   'from_col': 8,
#   'from_row': 12,
#   'value': 677},
#  {'category': 'Property\ncrime',
#   'country': 'Elmore',
#   'from_col': 8,
#   'from_row': 12,
#   'value': 677},
#  {'category': 'Burglary',
#   'country': 'Elmore',
#   'from_col': 9,
#   'from_row': 12,
#   'value': 223},
#  {'category': 'Burglary',
#   'country': 'Elmore',
#   'from_col': 9,
#   'from_row': 12,
#   'value': 223},
#  {'category': 'Burglary',
#   'country': 'Elmore',
#   'from_col': 9,
#   'from_row': 12,
#   'value': 223},
#  {'category': 'Burglary',
#   'country': 'Elmore',
#   'from_col': 9,
#   'from_row': 12,
#   'value': 223},
#  {'category': 'Burglary',
#   'country': 'Elmore',
#   'from_col': 9,
#   'from_row': 12,
#   'value': 223},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Elmore',
#   'from_col': 10,
#   'from_row': 12,
#   'value': 408},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Elmore',
#   'from_col': 10,
#   'from_row': 12,
#   'value': 408},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Elmore',
#   'from_col': 10,
#   'from_row': 12,
#   'value': 408},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Elmore',
#   'from_col': 10,
#   'from_row': 12,
#   'value': 408},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Elmore',
#   'from_col': 10,
#   'from_row': 12,
#   'value': 408},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Elmore',
#   'from_col': 11,
#   'from_row': 12,
#   'value': 46},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Elmore',
#   'from_col': 11,
#   'from_row': 12,
#   'value': 46},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Elmore',
#   'from_col': 11,
#   'from_row': 12,
#   'value': 46},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Elmore',
#   'from_col': 11,
#   'from_row': 12,
#   'value': 46},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Elmore',
#   'from_col': 11,
#   'from_row': 12,
#   'value': 46},
#  {'category': 'Violent\ncrime',
#   'country': 'Etowah',
#   'from_col': 2,
#   'from_row': 13,
#   'value': 135},
#  {'category': 'Violent\ncrime',
#   'country': 'Etowah',
#   'from_col': 2,
#   'from_row': 13,
#   'value': 135},
#  {'category': 'Violent\ncrime',
#   'country': 'Etowah',
#   'from_col': 2,
#   'from_row': 13,
#   'value': 135},
#  {'category': 'Violent\ncrime',
#   'country': 'Etowah',
#   'from_col': 2,
#   'from_row': 13,
#   'value': 135},
#  {'category': 'Violent\ncrime',
#   'country': 'Etowah',
#   'from_col': 2,
#   'from_row': 13,
#   'value': 135},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Etowah',
#   'from_col': 3,
#   'from_row': 13,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Etowah',
#   'from_col': 3,
#   'from_row': 13,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Etowah',
#   'from_col': 3,
#   'from_row': 13,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Etowah',
#   'from_col': 3,
#   'from_row': 13,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Etowah',
#   'from_col': 3,
#   'from_row': 13,
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Etowah',
#   'from_col': 4,
#   'from_row': 13,
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Etowah',
#   'from_col': 4,
#   'from_row': 13,
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Etowah',
#   'from_col': 4,
#   'from_row': 13,
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Etowah',
#   'from_col': 4,
#   'from_row': 13,
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Etowah',
#   'from_col': 4,
#   'from_row': 13,
#   'value': 20},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Etowah',
#   'from_col': 5,
#   'from_row': 13,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Etowah',
#   'from_col': 5,
#   'from_row': 13,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Etowah',
#   'from_col': 5,
#   'from_row': 13,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Etowah',
#   'from_col': 5,
#   'from_row': 13,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Etowah',
#   'from_col': 5,
#   'from_row': 13,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Etowah',
#   'from_col': 6,
#   'from_row': 13,
#   'value': 7},
#  {'category': 'Robbery',
#   'country': 'Etowah',
#   'from_col': 6,
#   'from_row': 13,
#   'value': 7},
#  {'category': 'Robbery',
#   'country': 'Etowah',
#   'from_col': 6,
#   'from_row': 13,
#   'value': 7},
#  {'category': 'Robbery',
#   'country': 'Etowah',
#   'from_col': 6,
#   'from_row': 13,
#   'value': 7},
#  {'category': 'Robbery',
#   'country': 'Etowah',
#   'from_col': 6,
#   'from_row': 13,
#   'value': 7},
#  {'category': 'Aggravated\nassault',
#   'country': 'Etowah',
#   'from_col': 7,
#   'from_row': 13,
#   'value': 107},
#  {'category': 'Aggravated\nassault',
#   'country': 'Etowah',
#   'from_col': 7,
#   'from_row': 13,
#   'value': 107},
#  {'category': 'Aggravated\nassault',
#   'country': 'Etowah',
#   'from_col': 7,
#   'from_row': 13,
#   'value': 107},
#  {'category': 'Aggravated\nassault',
#   'country': 'Etowah',
#   'from_col': 7,
#   'from_row': 13,
#   'value': 107},
#  {'category': 'Aggravated\nassault',
#   'country': 'Etowah',
#   'from_col': 7,
#   'from_row': 13,
#   'value': 107},
#  {'category': 'Property\ncrime',
#   'country': 'Etowah',
#   'from_col': 8,
#   'from_row': 13,
#   'value': 480},
#  {'category': 'Property\ncrime',
#   'country': 'Etowah',
#   'from_col': 8,
#   'from_row': 13,
#   'value': 480},
#  {'category': 'Property\ncrime',
#   'country': 'Etowah',
#   'from_col': 8,
#   'from_row': 13,
#   'value': 480},
#  {'category': 'Property\ncrime',
#   'country': 'Etowah',
#   'from_col': 8,
#   'from_row': 13,
#   'value': 480},
#  {'category': 'Property\ncrime',
#   'country': 'Etowah',
#   'from_col': 8,
#   'from_row': 13,
#   'value': 480},
#  {'category': 'Burglary',
#   'country': 'Etowah',
#   'from_col': 9,
#   'from_row': 13,
#   'value': 149},
#  {'category': 'Burglary',
#   'country': 'Etowah',
#   'from_col': 9,
#   'from_row': 13,
#   'value': 149},
#  {'category': 'Burglary',
#   'country': 'Etowah',
#   'from_col': 9,
#   'from_row': 13,
#   'value': 149},
#  {'category': 'Burglary',
#   'country': 'Etowah',
#   'from_col': 9,
#   'from_row': 13,
#   'value': 149},
#  {'category': 'Burglary',
#   'country': 'Etowah',
#   'from_col': 9,
#   'from_row': 13,
#   'value': 149},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Etowah',
#   'from_col': 10,
#   'from_row': 13,
#   'value': 255},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Etowah',
#   'from_col': 10,
#   'from_row': 13,
#   'value': 255},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Etowah',
#   'from_col': 10,
#   'from_row': 13,
#   'value': 255},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Etowah',
#   'from_col': 10,
#   'from_row': 13,
#   'value': 255},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Etowah',
#   'from_col': 10,
#   'from_row': 13,
#   'value': 255},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Etowah',
#   'from_col': 11,
#   'from_row': 13,
#   'value': 76},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Etowah',
#   'from_col': 11,
#   'from_row': 13,
#   'value': 76},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Etowah',
#   'from_col': 11,
#   'from_row': 13,
#   'value': 76},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Etowah',
#   'from_col': 11,
#   'from_row': 13,
#   'value': 76},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Etowah',
#   'from_col': 11,
#   'from_row': 13,
#   'value': 76},
#  {'category': 'Violent\ncrime',
#   'country': 'Geneva',
#   'from_col': 2,
#   'from_row': 14,
#   'value': 46},
#  {'category': 'Violent\ncrime',
#   'country': 'Geneva',
#   'from_col': 2,
#   'from_row': 14,
#   'value': 46},
#  {'category': 'Violent\ncrime',
#   'country': 'Geneva',
#   'from_col': 2,
#   'from_row': 14,
#   'value': 46},
#  {'category': 'Violent\ncrime',
#   'country': 'Geneva',
#   'from_col': 2,
#   'from_row': 14,
#   'value': 46},
#  {'category': 'Violent\ncrime',
#   'country': 'Geneva',
#   'from_col': 2,
#   'from_row': 14,
#   'value': 46},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Geneva',
#   'from_col': 3,
#   'from_row': 14,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Geneva',
#   'from_col': 3,
#   'from_row': 14,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Geneva',
#   'from_col': 3,
#   'from_row': 14,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Geneva',
#   'from_col': 3,
#   'from_row': 14,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Geneva',
#   'from_col': 3,
#   'from_row': 14,
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Geneva',
#   'from_col': 4,
#   'from_row': 14,
#   'value': 9},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Geneva',
#   'from_col': 4,
#   'from_row': 14,
#   'value': 9},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Geneva',
#   'from_col': 4,
#   'from_row': 14,
#   'value': 9},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Geneva',
#   'from_col': 4,
#   'from_row': 14,
#   'value': 9},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Geneva',
#   'from_col': 4,
#   'from_row': 14,
#   'value': 9},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Geneva',
#   'from_col': 5,
#   'from_row': 14,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Geneva',
#   'from_col': 5,
#   'from_row': 14,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Geneva',
#   'from_col': 5,
#   'from_row': 14,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Geneva',
#   'from_col': 5,
#   'from_row': 14,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Geneva',
#   'from_col': 5,
#   'from_row': 14,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Geneva',
#   'from_col': 6,
#   'from_row': 14,
#   'value': 2},
#  {'category': 'Robbery',
#   'country': 'Geneva',
#   'from_col': 6,
#   'from_row': 14,
#   'value': 2},
#  {'category': 'Robbery',
#   'country': 'Geneva',
#   'from_col': 6,
#   'from_row': 14,
#   'value': 2},
#  {'category': 'Robbery',
#   'country': 'Geneva',
#   'from_col': 6,
#   'from_row': 14,
#   'value': 2},
#  {'category': 'Robbery',
#   'country': 'Geneva',
#   'from_col': 6,
#   'from_row': 14,
#   'value': 2},
#  {'category': 'Aggravated\nassault',
#   'country': 'Geneva',
#   'from_col': 7,
#   'from_row': 14,
#   'value': 34},
#  {'category': 'Aggravated\nassault',
#   'country': 'Geneva',
#   'from_col': 7,
#   'from_row': 14,
#   'value': 34},
#  {'category': 'Aggravated\nassault',
#   'country': 'Geneva',
#   'from_col': 7,
#   'from_row': 14,
#   'value': 34},
#  {'category': 'Aggravated\nassault',
#   'country': 'Geneva',
#   'from_col': 7,
#   'from_row': 14,
#   'value': 34},
#  {'category': 'Aggravated\nassault',
#   'country': 'Geneva',
#   'from_col': 7,
#   'from_row': 14,
#   'value': 34},
#  {'category': 'Property\ncrime',
#   'country': 'Geneva',
#   'from_col': 8,
#   'from_row': 14,
# ...
#   'from_col': 3,
#   'from_row': 29,
#   'value': 3},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Shelby',
#   'from_col': 4,
#   'from_row': 29,
#   'value': 25},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Shelby',
#   'from_col': 4,
#   'from_row': 29,
#   'value': 25},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Shelby',
#   'from_col': 4,
#   'from_row': 29,
#   'value': 25},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Shelby',
#   'from_col': 4,
#   'from_row': 29,
#   'value': 25},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Shelby',
#   'from_col': 4,
#   'from_row': 29,
#   'value': 25},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Shelby',
#   'from_col': 5,
#   'from_row': 29,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Shelby',
#   'from_col': 5,
#   'from_row': 29,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Shelby',
#   'from_col': 5,
#   'from_row': 29,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Shelby',
#   'from_col': 5,
#   'from_row': 29,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Shelby',
#   'from_col': 5,
#   'from_row': 29,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Shelby',
#   'from_col': 6,
#   'from_row': 29,
#   'value': 8},
#  {'category': 'Robbery',
#   'country': 'Shelby',
#   'from_col': 6,
#   'from_row': 29,
#   'value': 8},
#  {'category': 'Robbery',
#   'country': 'Shelby',
#   'from_col': 6,
#   'from_row': 29,
#   'value': 8},
#  {'category': 'Robbery',
#   'country': 'Shelby',
#   'from_col': 6,
#   'from_row': 29,
#   'value': 8},
#  {'category': 'Robbery',
#   'country': 'Shelby',
#   'from_col': 6,
#   'from_row': 29,
#   'value': 8},
#  {'category': 'Aggravated\nassault',
#   'country': 'Shelby',
#   'from_col': 7,
#   'from_row': 29,
#   'value': 75},
#  {'category': 'Aggravated\nassault',
#   'country': 'Shelby',
#   'from_col': 7,
#   'from_row': 29,
#   'value': 75},
#  {'category': 'Aggravated\nassault',
#   'country': 'Shelby',
#   'from_col': 7,
#   'from_row': 29,
#   'value': 75},
#  {'category': 'Aggravated\nassault',
#   'country': 'Shelby',
#   'from_col': 7,
#   'from_row': 29,
#   'value': 75},
#  {'category': 'Aggravated\nassault',
#   'country': 'Shelby',
#   'from_col': 7,
#   'from_row': 29,
#   'value': 75},
#  {'category': 'Property\ncrime',
#   'country': 'Shelby',
#   'from_col': 8,
#   'from_row': 29,
#   'value': 886},
#  {'category': 'Property\ncrime',
#   'country': 'Shelby',
#   'from_col': 8,
#   'from_row': 29,
#   'value': 886},
#  {'category': 'Property\ncrime',
#   'country': 'Shelby',
#   'from_col': 8,
#   'from_row': 29,
#   'value': 886},
#  {'category': 'Property\ncrime',
#   'country': 'Shelby',
#   'from_col': 8,
#   'from_row': 29,
#   'value': 886},
#  {'category': 'Property\ncrime',
#   'country': 'Shelby',
#   'from_col': 8,
#   'from_row': 29,
#   'value': 886},
#  {'category': 'Burglary',
#   'country': 'Shelby',
#   'from_col': 9,
#   'from_row': 29,
#   'value': 251},
#  {'category': 'Burglary',
#   'country': 'Shelby',
#   'from_col': 9,
#   'from_row': 29,
#   'value': 251},
#  {'category': 'Burglary',
#   'country': 'Shelby',
#   'from_col': 9,
#   'from_row': 29,
#   'value': 251},
#  {'category': 'Burglary',
#   'country': 'Shelby',
#   'from_col': 9,
#   'from_row': 29,
#   'value': 251},
#  {'category': 'Burglary',
#   'country': 'Shelby',
#   'from_col': 9,
#   'from_row': 29,
#   'value': 251},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Shelby',
#   'from_col': 10,
#   'from_row': 29,
#   'value': 537},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Shelby',
#   'from_col': 10,
#   'from_row': 29,
#   'value': 537},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Shelby',
#   'from_col': 10,
#   'from_row': 29,
#   'value': 537},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Shelby',
#   'from_col': 10,
#   'from_row': 29,
#   'value': 537},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Shelby',
#   'from_col': 10,
#   'from_row': 29,
#   'value': 537},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Shelby',
#   'from_col': 11,
#   'from_row': 29,
#   'value': 98},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Shelby',
#   'from_col': 11,
#   'from_row': 29,
#   'value': 98},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Shelby',
#   'from_col': 11,
#   'from_row': 29,
#   'value': 98},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Shelby',
#   'from_col': 11,
#   'from_row': 29,
#   'value': 98},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Shelby',
#   'from_col': 11,
#   'from_row': 29,
#   'value': 98},
#  {'category': 'Violent\ncrime',
#   'country': 'St. Clair',
#   'from_col': 2,
#   'from_row': 30,
#   'value': 236},
#  {'category': 'Violent\ncrime',
#   'country': 'St. Clair',
#   'from_col': 2,
#   'from_row': 30,
#   'value': 236},
#  {'category': 'Violent\ncrime',
#   'country': 'St. Clair',
#   'from_col': 2,
#   'from_row': 30,
#   'value': 236},
#  {'category': 'Violent\ncrime',
#   'country': 'St. Clair',
#   'from_col': 2,
#   'from_row': 30,
#   'value': 236},
#  {'category': 'Violent\ncrime',
#   'country': 'St. Clair',
#   'from_col': 2,
#   'from_row': 30,
#   'value': 236},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'St. Clair',
#   'from_col': 3,
#   'from_row': 30,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'St. Clair',
#   'from_col': 3,
#   'from_row': 30,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'St. Clair',
#   'from_col': 3,
#   'from_row': 30,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'St. Clair',
#   'from_col': 3,
#   'from_row': 30,
#   'value': 0},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'St. Clair',
#   'from_col': 3,
#   'from_row': 30,
#   'value': 0},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'St. Clair',
#   'from_col': 4,
#   'from_row': 30,
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'St. Clair',
#   'from_col': 4,
#   'from_row': 30,
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'St. Clair',
#   'from_col': 4,
#   'from_row': 30,
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'St. Clair',
#   'from_col': 4,
#   'from_row': 30,
#   'value': 20},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'St. Clair',
#   'from_col': 4,
#   'from_row': 30,
#   'value': 20},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'St. Clair',
#   'from_col': 5,
#   'from_row': 30,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'St. Clair',
#   'from_col': 5,
#   'from_row': 30,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'St. Clair',
#   'from_col': 5,
#   'from_row': 30,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'St. Clair',
#   'from_col': 5,
#   'from_row': 30,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'St. Clair',
#   'from_col': 5,
#   'from_row': 30,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'St. Clair',
#   'from_col': 6,
#   'from_row': 30,
#   'value': 4},
#  {'category': 'Robbery',
#   'country': 'St. Clair',
#   'from_col': 6,
#   'from_row': 30,
#   'value': 4},
#  {'category': 'Robbery',
#   'country': 'St. Clair',
#   'from_col': 6,
#   'from_row': 30,
#   'value': 4},
#  {'category': 'Robbery',
#   'country': 'St. Clair',
#   'from_col': 6,
#   'from_row': 30,
#   'value': 4},
#  {'category': 'Robbery',
#   'country': 'St. Clair',
#   'from_col': 6,
#   'from_row': 30,
#   'value': 4},
#  {'category': 'Aggravated\nassault',
#   'country': 'St. Clair',
#   'from_col': 7,
#   'from_row': 30,
#   'value': 212},
#  {'category': 'Aggravated\nassault',
#   'country': 'St. Clair',
#   'from_col': 7,
#   'from_row': 30,
#   'value': 212},
#  {'category': 'Aggravated\nassault',
#   'country': 'St. Clair',
#   'from_col': 7,
#   'from_row': 30,
#   'value': 212},
#  {'category': 'Aggravated\nassault',
#   'country': 'St. Clair',
#   'from_col': 7,
#   'from_row': 30,
#   'value': 212},
#  {'category': 'Aggravated\nassault',
#   'country': 'St. Clair',
#   'from_col': 7,
#   'from_row': 30,
#   'value': 212},
#  {'category': 'Property\ncrime',
#   'country': 'St. Clair',
#   'from_col': 8,
#   'from_row': 30,
#   'value': 541},
#  {'category': 'Property\ncrime',
#   'country': 'St. Clair',
#   'from_col': 8,
#   'from_row': 30,
#   'value': 541},
#  {'category': 'Property\ncrime',
#   'country': 'St. Clair',
#   'from_col': 8,
#   'from_row': 30,
#   'value': 541},
#  {'category': 'Property\ncrime',
#   'country': 'St. Clair',
#   'from_col': 8,
#   'from_row': 30,
#   'value': 541},
#  {'category': 'Property\ncrime',
#   'country': 'St. Clair',
#   'from_col': 8,
#   'from_row': 30,
#   'value': 541},
#  {'category': 'Burglary',
#   'country': 'St. Clair',
#   'from_col': 9,
#   'from_row': 30,
#   'value': 214},
#  {'category': 'Burglary',
#   'country': 'St. Clair',
#   'from_col': 9,
#   'from_row': 30,
#   'value': 214},
#  {'category': 'Burglary',
#   'country': 'St. Clair',
#   'from_col': 9,
#   'from_row': 30,
#   'value': 214},
#  {'category': 'Burglary',
#   'country': 'St. Clair',
#   'from_col': 9,
#   'from_row': 30,
#   'value': 214},
#  {'category': 'Burglary',
#   'country': 'St. Clair',
#   'from_col': 9,
#   'from_row': 30,
#   'value': 214},
#  {'category': 'Larceny-\ntheft',
#   'country': 'St. Clair',
#   'from_col': 10,
#   'from_row': 30,
#   'value': 303},
#  {'category': 'Larceny-\ntheft',
#   'country': 'St. Clair',
#   'from_col': 10,
#   'from_row': 30,
#   'value': 303},
#  {'category': 'Larceny-\ntheft',
#   'country': 'St. Clair',
#   'from_col': 10,
#   'from_row': 30,
#   'value': 303},
#  {'category': 'Larceny-\ntheft',
#   'country': 'St. Clair',
#   'from_col': 10,
#   'from_row': 30,
#   'value': 303},
#  {'category': 'Larceny-\ntheft',
#   'country': 'St. Clair',
#   'from_col': 10,
#   'from_row': 30,
#   'value': 303},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'St. Clair',
#   'from_col': 11,
#   'from_row': 30,
#   'value': 24},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'St. Clair',
#   'from_col': 11,
#   'from_row': 30,
#   'value': 24},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'St. Clair',
#   'from_col': 11,
#   'from_row': 30,
#   'value': 24},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'St. Clair',
#   'from_col': 11,
#   'from_row': 30,
#   'value': 24},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'St. Clair',
#   'from_col': 11,
#   'from_row': 30,
#   'value': 24},
#  {'category': 'Violent\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 2,
#   'from_row': 31,
#   'value': 185},
#  {'category': 'Violent\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 2,
#   'from_row': 31,
#   'value': 185},
#  {'category': 'Violent\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 2,
#   'from_row': 31,
#   'value': 185},
#  {'category': 'Violent\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 2,
#   'from_row': 31,
#   'value': 185},
#  {'category': 'Violent\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 2,
#   'from_row': 31,
#   'value': 185},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Tuscaloosa',
#   'from_col': 3,
#   'from_row': 31,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Tuscaloosa',
#   'from_col': 3,
#   'from_row': 31,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Tuscaloosa',
#   'from_col': 3,
#   'from_row': 31,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Tuscaloosa',
#   'from_col': 3,
#   'from_row': 31,
#   'value': 1},
#  {'category': 'Murder and\nnonnegligent\nmanslaughter',
#   'country': 'Tuscaloosa',
#   'from_col': 3,
#   'from_row': 31,
#   'value': 1},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Tuscaloosa',
#   'from_col': 4,
#   'from_row': 31,
#   'value': 6},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Tuscaloosa',
#   'from_col': 4,
#   'from_row': 31,
#   'value': 6},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Tuscaloosa',
#   'from_col': 4,
#   'from_row': 31,
#   'value': 6},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Tuscaloosa',
#   'from_col': 4,
#   'from_row': 31,
#   'value': 6},
#  {'category': 'Rape\n(revised\ndefinition)1',
#   'country': 'Tuscaloosa',
#   'from_col': 4,
#   'from_row': 31,
#   'value': 6},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Tuscaloosa',
#   'from_col': 5,
#   'from_row': 31,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Tuscaloosa',
#   'from_col': 5,
#   'from_row': 31,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Tuscaloosa',
#   'from_col': 5,
#   'from_row': 31,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Tuscaloosa',
#   'from_col': 5,
#   'from_row': 31,
#   'value': ''},
#  {'category': 'Rape\n(legacy\ndefinition)2',
#   'country': 'Tuscaloosa',
#   'from_col': 5,
#   'from_row': 31,
#   'value': ''},
#  {'category': 'Robbery',
#   'country': 'Tuscaloosa',
#   'from_col': 6,
#   'from_row': 31,
#   'value': 22},
#  {'category': 'Robbery',
#   'country': 'Tuscaloosa',
#   'from_col': 6,
#   'from_row': 31,
#   'value': 22},
#  {'category': 'Robbery',
#   'country': 'Tuscaloosa',
#   'from_col': 6,
#   'from_row': 31,
#   'value': 22},
#  {'category': 'Robbery',
#   'country': 'Tuscaloosa',
#   'from_col': 6,
#   'from_row': 31,
#   'value': 22},
#  {'category': 'Robbery',
#   'country': 'Tuscaloosa',
#   'from_col': 6,
#   'from_row': 31,
#   'value': 22},
#  {'category': 'Aggravated\nassault',
#   'country': 'Tuscaloosa',
#   'from_col': 7,
#   'from_row': 31,
#   'value': 156},
#  {'category': 'Aggravated\nassault',
#   'country': 'Tuscaloosa',
#   'from_col': 7,
#   'from_row': 31,
#   'value': 156},
#  {'category': 'Aggravated\nassault',
#   'country': 'Tuscaloosa',
#   'from_col': 7,
#   'from_row': 31,
#   'value': 156},
#  {'category': 'Aggravated\nassault',
#   'country': 'Tuscaloosa',
#   'from_col': 7,
#   'from_row': 31,
#   'value': 156},
#  {'category': 'Aggravated\nassault',
#   'country': 'Tuscaloosa',
#   'from_col': 7,
#   'from_row': 31,
#   'value': 156},
#  {'category': 'Property\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 8,
#   'from_row': 31,
#   'value': 1234},
#  {'category': 'Property\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 8,
#   'from_row': 31,
#   'value': 1234},
#  {'category': 'Property\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 8,
#   'from_row': 31,
#   'value': 1234},
#  {'category': 'Property\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 8,
#   'from_row': 31,
#   'value': 1234},
#  {'category': 'Property\ncrime',
#   'country': 'Tuscaloosa',
#   'from_col': 8,
#   'from_row': 31,
#   'value': 1234},
#  {'category': 'Burglary',
#   'country': 'Tuscaloosa',
#   'from_col': 9,
#   'from_row': 31,
#   'value': 387},
#  {'category': 'Burglary',
#   'country': 'Tuscaloosa',
#   'from_col': 9,
#   'from_row': 31,
#   'value': 387},
#  {'category': 'Burglary',
#   'country': 'Tuscaloosa',
#   'from_col': 9,
#   'from_row': 31,
#   'value': 387},
#  {'category': 'Burglary',
#   'country': 'Tuscaloosa',
#   'from_col': 9,
#   'from_row': 31,
#   'value': 387},
#  {'category': 'Burglary',
#   'country': 'Tuscaloosa',
#   'from_col': 9,
#   'from_row': 31,
#   'value': 387},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 10,
#   'from_row': 31,
#   'value': 726},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 10,
#   'from_row': 31,
#   'value': 726},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 10,
#   'from_row': 31,
#   'value': 726},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 10,
#   'from_row': 31,
#   'value': 726},
#  {'category': 'Larceny-\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 10,
#   'from_row': 31,
#   'value': 726},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 11,
#   'from_row': 31,
#   'value': 121},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 11,
#   'from_row': 31,
#   'value': 121},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 11,
#   'from_row': 31,
#   'value': 121},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 11,
#   'from_row': 31,
#   'value': 121},
#  {'category': 'Motor\nvehicle\ntheft',
#   'country': 'Tuscaloosa',
#   'from_col': 11,
#   'from_row': 31,
#   'value': 121}]

# %% [markdown]
# ## Wrap it up in ETK module and post processing
#
# The below example shows how to use this extractor in ETK module. The extractor's variable syntax only supports using a single built-in varaible or a coordinate. All the post processings need to be done after extraction.

# %%
import os, sys
import pprint
from etk.etk import ETK
from etk.etk_module import ETKModule
from etk.extractors.excel_extractor import ExcelExtractor
from etk.utilities import Utility


class ExampleETKModule(ETKModule):
    """
    Abstract class for extraction module
    """
    def __init__(self, etk):
        ETKModule.__init__(self, etk)
        self.ee = ExcelExtractor()

    def document_selector(self, doc):
        return 'file_path' in doc.cdr_document

    def process_document(self, doc):
        """
        Add your code for processing the document
        """

        variables = {
            'value': '$col,$row',
            'country': '$B,$row',
            'category': '$col,$6',
            'from_row': '$row',
            'from_col': '$col'
        }

        raw_extractions = self.ee.extract(doc.cdr_document['file_path'], '16tbl08al', ['C,7', 'M,33'], variables)

        extracted_docs = []
        for d in raw_extractions:
            # post processing
            d['category'] = d['category'].replace('\n', ' ').strip()
            d['country'] = d['country'].replace('\n', ' ').strip()
            d['from_row'] = int(d['from_row'])
            d['from_col'] = int(d['from_col'])
            
            # create sub document
            d['doc_id'] = Utility.create_doc_id_from_json(d)
            extracted_docs.append(etk.create_document(d))

        return extracted_docs


# if __name__ == "__main__":
etk = ETK(modules=ExampleETKModule)
doc = etk.create_document({'file_path': 'alabama.xls'})
docs = etk.process_ems(doc)

for d in docs[1:11]:
    print(d.value)
# Out:
# {'value': 73, 'country': 'Autauga', 'category': 'Violent crime', 'from_row': 6, 'from_col': 2, 'doc_id': '6ee778244362c177d0b365fe8ffcde3684e01fe956af73e923ea0d0c7fcad039'}
# {'value': 73, 'country': 'Autauga', 'category': 'Violent crime', 'from_row': 6, 'from_col': 2, 'doc_id': '6ee778244362c177d0b365fe8ffcde3684e01fe956af73e923ea0d0c7fcad039'}
# {'value': 73, 'country': 'Autauga', 'category': 'Violent crime', 'from_row': 6, 'from_col': 2, 'doc_id': '6ee778244362c177d0b365fe8ffcde3684e01fe956af73e923ea0d0c7fcad039'}
# {'value': 73, 'country': 'Autauga', 'category': 'Violent crime', 'from_row': 6, 'from_col': 2, 'doc_id': '6ee778244362c177d0b365fe8ffcde3684e01fe956af73e923ea0d0c7fcad039'}
# {'value': 73, 'country': 'Autauga', 'category': 'Violent crime', 'from_row': 6, 'from_col': 2, 'doc_id': '6ee778244362c177d0b365fe8ffcde3684e01fe956af73e923ea0d0c7fcad039'}
# {'value': 1, 'country': 'Autauga', 'category': 'Murder and nonnegligent manslaughter', 'from_row': 6, 'from_col': 3, 'doc_id': '289627d9fc94fb52fb7bdbf7980e6cecfd152496f5fd51b974581cdf0439ee6a'}
# {'value': 1, 'country': 'Autauga', 'category': 'Murder and nonnegligent manslaughter', 'from_row': 6, 'from_col': 3, 'doc_id': '289627d9fc94fb52fb7bdbf7980e6cecfd152496f5fd51b974581cdf0439ee6a'}
# {'value': 1, 'country': 'Autauga', 'category': 'Murder and nonnegligent manslaughter', 'from_row': 6, 'from_col': 3, 'doc_id': '289627d9fc94fb52fb7bdbf7980e6cecfd152496f5fd51b974581cdf0439ee6a'}
# {'value': 1, 'country': 'Autauga', 'category': 'Murder and nonnegligent manslaughter', 'from_row': 6, 'from_col': 3, 'doc_id': '289627d9fc94fb52fb7bdbf7980e6cecfd152496f5fd51b974581cdf0439ee6a'}
# {'value': 1, 'country': 'Autauga', 'category': 'Murder and nonnegligent manslaughter', 'from_row': 6, 'from_col': 3, 'doc_id': '289627d9fc94fb52fb7bdbf7980e6cecfd152496f5fd51b974581cdf0439ee6a'}
