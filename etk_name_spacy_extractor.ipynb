# %% [markdown]
# # Custom Spacy Rules

# %%
sampe_rules = {
  "rules": [
      {
      "identifier": "an indentifier",
      "description": "a description",
      "is_active": "true/false",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["tOWN", "job"],
          "capitalization": ["title", "upper", "mixed"],
          "part_of_speech": ["noun", "pronoun"],
          "length": [],
          "prefix": "ssss",
          "suffix": "",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["lower", "upper", "mixed"],
          "part_of_speech": [],
          "length": [5, 7],
          "prefix": "SA",
          "suffix": "WF",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "EEW",
          "suffix": "RHI",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "number",
          "tokens": [],
          "length": [],
          "prefix": [],
          "suffix": [],
          "min":"",
          "max":"",
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        },
        {
          "type": "shape",
          "shapes": ["xxxx", "xxxxxx", "XXXXXdd.dddXXxxxxxxx"],
          "part_of_speech": [],
          "prefix": "ss",
          "suffix": "pp",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true"
        },
        {
          "type": "punctuation",
          "token": [",", "?"],
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true"
        },
        {
          "type": "symbol",
          "token": [],
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        }
      ]
    }
  ]
}

# %%
import json
from etk.core import Core
c = Core()

# %%
# my name is 
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and, My names is Alanda")
t.append(u"Name : Sara . I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO ")
t.append(u"I'm Ashley I'm bored ")
t.append(u"this is Ashley1 I'm bored This is Ashley2")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_01",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["my"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["name", "names"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["is"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "false",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))
    
config = dict()
config['field_name'] = 'field01'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and, My names is Alanda
#  Name : Sara . I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO
#  I'm Ashley I'm bored
#  this is Ashley1 I'm bored This is Ashley2
# RESULTS:
# [{'context': {'start': 31, 'end': 34, 'rule_id': 0}, 'value': 'is'}, {'context': {'start': 36, 'end': 39, 'rule_id': 0}, 'value': 'Monica'}, {'context': {'start': 31, 'end': 35, 'rule_id': 0}, 'value': 'Ashley'}, {'context': {'start': 45, 'end': 49, 'rule_id': 0}, 'value': 'Alanda'}]

# %%
#i am Ashly
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. it is Jessica here .I cant say the name onnn here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and")
t.append(u"Name : Sara . I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO ")
t.append(u"I'm Ashley I'm bored ")
t.append(u"this is ALAAA i am Ashley I am bored This is Ashley2")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_02",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["i"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
         {
          "type": "word",
          "token": ["am"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

config = dict()
config['field_name'] = 'field02'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. it is Jessica here .I cant say the name onnn here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and
#  Name : Sara . I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO
#  I'm Ashley I'm bored
#  this is ALAAA i am Ashley I am bored This is Ashley2
# RESULTS:
# [{'context': {'start': 89, 'end': 92, 'rule_id': 0}, 'value': 'Ashley'}]

# %%
#name: Name:  Name :
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. it is Jessica here .I cant say the name onnn here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and")
t.append(u"Name : Sara . I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO ")
t.append(u"I'm Ashley I'm bored ")
t.append(u"this is Ashley1 I'm bored This is Ashley2")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_03",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["name"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
         {
          "type": "punctuation",
          "token": [":"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

config = dict()
config['field_name'] = 'field03'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. it is Jessica here .I cant say the name onnn here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and
#  Name : Sara . I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO
#  I'm Ashley I'm bored
#  this is Ashley1 I'm bored This is Ashley2
# RESULTS:
# [{'context': {'start': 50, 'end': 53, 'rule_id': 0}, 'value': 'Sara'}, {'context': {'start': 60, 'end': 63, 'rule_id': 0}, 'value': 'JILL'}, {'context': {'start': 64, 'end': 67, 'rule_id': 0}, 'value': 'Jessie'}]

# %%
# it is 
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. it is Jessica here .I cant say the name onnn here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and")
t.append(u"Name : Sara . I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO ")
t.append(u"I'm Ashley I'm bored ")
t.append(u"this is Ashley1 I'm bored This is Ashley2")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_04",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["it"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
         {
          "type": "punctuation",
          "token": ["is"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

config = dict()
config['field_name'] = 'field04'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. it is Jessica here .I cant say the name onnn here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and
#  Name : Sara . I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO
#  I'm Ashley I'm bored
#  this is Ashley1 I'm bored This is Ashley2
# RESULTS:
# [{'context': {'start': 19, 'end': 22, 'rule_id': 0}, 'value': 'Jessica'}]

# %%
# this is , This is
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and")
t.append(u"Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO ")
t.append(u"I'm Ashley I'm bored ")
t.append(u"vvv this is Ashley1 I'm bored This is Ashley2")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["this"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["is"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}


d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

config = dict()
config['field_name'] = 'field04'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and
#  Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO
#  I'm Ashley I'm bored
#  vvv this is Ashley1 I'm bored This is Ashley2
# RESULTS:
# [{'context': {'start': 57, 'end': 60, 'rule_id': 0}, 'value': 'Amy'}]

# %%
#I'm
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and")
t.append(u"Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO ")
t.append(u"I'm Ashley I'm bored ")
t.append(u"vvv this is Ashley1 I'm bored This is Ashley2")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["i"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["'m"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}


d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

config = dict()
config['field_name'] = 'field04'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and
#  Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO
#  I'm Ashley I'm bored
#  vvv this is Ashley1 I'm bored This is Ashley2
# RESULTS:
# []

# %%
#it's
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and")
t.append(u"Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO ")
t.append(u"I'm Ashley I'm bored ")
t.append(u"vvv this is Ashley I'm bored This is Ashley2")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["it"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["'s"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}


d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

config = dict()
config['field_name'] = 'field04'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and
#  Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO
#  I'm Ashley I'm bored
#  vvv this is Ashley I'm bored This is Ashley2
# RESULTS:
# []

# %%
#Ashley (702)
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and")
t.append(u"Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702) 628-9035 XOXO Asssss (7022)628-903  Jessica 7135975313")
t.append(u"I'm Ashley I'm bored ")
t.append(u"vvv this is Ashley I'm bored This is Ashley")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "punctuation",
          "token": ["("],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "shape",
          "shapes": ["ddd"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}


d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

config = dict()
config['field_name'] = 'field04'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and
#  Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie
#  Ashley (702) 628-9035 XOXO Asssss (7022)628-903  Jessica 7135975313
#  I'm Ashley I'm bored
#  vvv this is Ashley I'm bored This is Ashley
# RESULTS:
# [{'context': {'start': 74, 'end': 77, 'rule_id': 0}, 'value': 'Ashley'}]

# %%
#Jessica 7135975313
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,")
t.append(u"Hi Gentlemen, My name is Ashley . my name Monica I am the one and")
t.append(u"Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO   Jessica 7135975313")
t.append(u"I'm Ashley I'm bored ")
t.append(u"vvv this is Ashley I'm bored This is Ashley")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "shape",
          "shapes": ["dddddddddd"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}


d = dict()
d['text'] = "\n ".join(t)
print d['text']
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

config = dict()
config['field_name'] = 'field04'

print "RESULTS:"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hello guy's, it's Jessica here from the #@%%% Spa. it is JJJJ here .I cant say the name onnn here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and
#  Name : Sara . this is ashley  This is Amy I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO   Jessica 7135975313
#  I'm Ashley I'm bored
#  vvv this is Ashley I'm bored This is Ashley
# RESULTS:
# [{'context': {'start': 82, 'end': 84, 'rule_id': 0}, 'value': 'Jessica'}]
