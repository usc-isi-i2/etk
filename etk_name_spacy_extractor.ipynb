# %% [markdown]
# # Custom Spacy Rules

# %%
sampe_rules = {
  "rules": [
      {
      "identifier": "an indentifier",
      "description": "a description",
      "is_active": "true/false",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["tOWN", "job"],
          "capitalization": ["title", "upper", "mixed"],
          "part_of_speech": ["noun", "pronoun"],
          "length": [],
          "prefix": "ssss",
          "suffix": "",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["lower", "upper", "mixed"],
          "part_of_speech": [],
          "length": [5, 7],
          "prefix": "SA",
          "suffix": "WF",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "EEW",
          "suffix": "RHI",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "number",
          "tokens": [],
          "length": [],
          "prefix": [],
          "suffix": [],
          "min":"",
          "max":"",
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        },
        {
          "type": "shape",
          "shapes": ["xxxx", "xxxxxx", "XXXXXdd.dddXXxxxxxxx"],
          "part_of_speech": [],
          "prefix": "ss",
          "suffix": "pp",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true"
        },
        {
          "type": "punctuation",
          "token": [",", "?"],
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true"
        },
        {
          "type": "symbol",
          "token": [],
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        }
      ]
    }
  ]
}

# %%
import json
from etk.core import Core
c = Core()

# %%
# Text to test the rules
t = []
t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,")
t.append(u"Hi Gentlemen, My name is Ashley . my names Monica I am the one and, My names is Alanda")
t.append(u"Name : Sara . I am Thee one and, Name: JILL , Name:Jessie")
t.append(u"Ashley (702)628-9035 XOXO . Aslll (702) 628-9035 XOXO Alppp 7026289035")
t.append(u"I'm Ashley I'm bored i am All, I am ALL")
t.append(u"this is Ashley1 I'm bored This is Ashley2")

d = dict()
d['text'] = "\n ".join(t)
d['simple_tokens_original_case'] = c.extract_tokens_from_crf(c.extract_crftokens(d['text'], lowercase=False))

print d

config = dict()
config['field_name'] = 'field02'
# Out:
# {'text': u"Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,\n Hi Gentlemen, My name is Ashley . my names Monica I am the one and, My namess is Alanda\n Name : Sara . I am Thee one and, Name: JILL , Name:Jessie\n Ashley (702)628-9035 XOXO . Aslll (702) 628-9035 XOXO Alppp 7026289035\n I'm Ashley I'm bored i am All, I am ALL\n this is Ashley1 I'm bored This is Ashley2", 'simple_tokens_original_case': [u'Hello', u'guy', u"'", u's', u',', u'it', u"'", u's', u'Jessica', u'here', u'from', u'the', u'#', u'@', u'%', u'%', u'%', u'Spa', u'.', u'I', u'cant', u'say', u'the', u'name', u'on', u'here', u',', u'\n', u'Hi', u'Gentlemen', u',', u'My', u'name', u'is', u'Ashley', u'.', u'my', u'names', u'Monica', u'I', u'am', u'the', u'one', u'and', u',', u'My', u'namess', u'is', u'Alanda', u'\n', u'Name', u':', u'Sara', u'.', u'I', u'am', u'Thee', u'one', u'and', u',', u'Name', u':', u'JILL', u',', u'Name', u':', u'Jessie', u'\n', u'Ashley', u'(', u'702', u')', u'628', u
# ...

# %%
# my name / names is

field_rules = {
  "rules": [
      {
      "identifier": "name_rule_01",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["my"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["name", "names"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["is"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "false",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

print "text:", d['text']
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
results
# Out:
# text: Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,
#  Hi Gentlemen, My name is Ashley . my names Monica I am the one and, My namess is Alanda
#  Name : Sara . I am Thee one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO . Aslll (702) 628-9035 XOXO Alppp 7026289035
#  I'm Ashley I'm bored i am All, I am ALL
#  this is Ashley1 I'm bored This is Ashley2
# [
#   {
#     "context": {
#       "start": 31,
#       "end": 35,
#       "rule_id": 0
#     },
#     "value": "Ashley"
#   }
# ]
# [{'context': {'end': 35, 'rule_id': 0, 'start': 31}, 'value': 'Ashley'}]

# %%
#i am 
field_rules = {
  "rules": [
      {
      "identifier": "name_rule_02",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["i"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
         {
          "type": "word",
          "token": ["am"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title", "upper"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

print "text:", d['text']
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
results


def text_rule(rule, text, answer):
    answer_lst = []
    results = c.extract_using_custom_spacy(d, config, field_rules=rule)
    for i in range(len(results)):
        answer_lst.append(results[i]['value'])      
    if answer_lst == answer:
        return True
    else:
        return False
answer = ['Thee', 'All']
text_rule(field_rules, t, answer )
# Out:
# text: Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,
#  Hi Gentlemen, My name is Ashley . my namee Monica I am the one and, My namess is Alanda
#  Name : Sara . I am Thee one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO . Aslll (702) 628-9035 XOXO Alppp 7026289035
#  I'm Ashley I'm bored i am All, I am ALL
#  this is Ashley1 I'm bored This is Ashley2
# [
#   {
#     "context": {
#       "start": 54,
#       "end": 57,
#       "rule_id": 0
#     },
#     "value": "Thee"
#   },
#   {
#     "context": {
#       "start": 96,
#       "end": 99,
#       "rule_id": 0
#     },
#     "value": "All"
#   }
# ]
# [{'context': {'start': 54, 'end': 57, 'rule_id': 0}, 'value': 'Thee'}, {'context': {'start': 96, 'end': 99, 'rule_id': 0}, 'value': 'All'}]
# <type 'dict'>
# 2
# Thee
# ['Thee', 'All']
# [
#   {
#     "context": {
#       "start": 54,
#       "end": 57,
#       "rule_id": 0
#     },
#     "value": "Thee"
#   },
#   {
#     "context": {
# ...

# %%
# name :   Name:
field_rules = {
  "rules": [
      {
      "identifier": "name_rule_03",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["name"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
         {
          "type": "punctuation",
          "token": [":"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

print "text:", d['text']
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
results

def text_rule(rule, text, answer):
    answer_lst = []
    results = c.extract_using_custom_spacy(d, config, field_rules=rule)
    for i in range(len(results)):
        answer_lst.append(results[i]['value'])      
    if answer_lst == answer:
        return True
    else:
        return False
answer = ['Sara','JILL']
text_rule(field_rules, t, answer )
# Out:
# text: Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,
#  Hi Gentlemen, My name is Ashley . my namee Monica I am the one and, My namess is Alanda
#  Name : Sara . I am Thee one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO . Aslll (702) 628-9035 XOXO Alppp 7026289035
#  I'm Ashley I'm bored i am All, I am ALL
#  this is Ashley1 I'm bored This is Ashley2
# [
#   {
#     "context": {
#       "start": 50,
#       "end": 53,
#       "rule_id": 0
#     },
#     "value": "Sara"
#   },
#   {
#     "context": {
#       "start": 60,
#       "end": 63,
#       "rule_id": 0
#     },
#     "value": "JILL"
#   }
# ]
# [
#   {
#     "context": {
#       "start": 50,
#       "end": 53,
#       "rule_id": 0
#     },
#     "value": "Sara"
#   },
#   {
#     "context": {
#       "start": 60,
#       "end": 63,
#       "rule_id": 0
#     },
#     "value": "JILL"
#   }
# ]
# True

# %%
# it is 

field_rules = {
  "rules": [
      {
      "identifier": "name_rule_04",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["it"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
         {
          "type": "punctuation",
          "token": ["is"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

print "text:", d['text']
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
results
# Out:
# text: Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,
#  Hi Gentlemen, My name is Ashley . my namee Monica I am the one and, My namess is Alanda
#  Name : Sara . I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO . Aslll (702) 628-9035 XOXO Alppp 7026289035
#  I'm Ashley I'm bored i am All, I am ALL
#  this is Ashley1 I'm bored This is Ashley2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-95abda2b3963> in <module>()
#      54
#      55 print "text:", d['text']
# ---> 56 results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
#      57 results
#
# /Users/jiayuanding/etk/etk/core.pyc in extract_using_custom_spacy(self, d, config, field_rules)
#     975         # call the custom spacy extractor
#     976         nlp_doc = self.nlp(d[_SIMPLE_TOKENS_ORIGINAL_CASE])
# ...

# %%
# this is , This is

field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["this"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["is"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}


print "text:", d['text']
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# text: Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,
#  Hi Gentlemen, My name is Ashley . my name Monica I am the one and, My names is Alanda
#  Name : Sara . I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO . Aslll (702) 628-9035 XOXO Alppp 7026289035
#  I'm Ashley I'm bored i am All, I am ALL
#  this is Ashley1 I'm bored This is Ashley2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-a26ac71b9e8f> in <module>()
#      55
#      56 print "text:", d['text']
# ---> 57 results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
#      58 print results
#
# /Users/jiayuanding/etk/etk/core.pyc in extract_using_custom_spacy(self, d, config, field_rules)
#     975         # call the custom spacy extractor
#     976         nlp_doc = self.nlp(d[_SIMPLE_TOKENS_ORIGINAL_CASE])
# ...

# %%
#I'm

field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["i"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["'"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
          {
          "type": "word",
          "token": ["m"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

print "text:", d['text']
print "tokens:", d['simple_tokens_original_case']
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
results
# Out:
# text: Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,
#  Hi Gentlemen, My name is Ashley . my namee Monica I am the one and, My namess is Alanda
#  Name : Sara . I am the one and, Name: JILL , Name:Jessie
#  Ashley (702)628-9035 XOXO . Aslll (702) 628-9035 XOXO Alppp 7026289035
#  I'm Ashley I'm bored i am All, I am ALL
#  this is Ashley1 I'm bored This is Ashley2
# ...

# %%
#it's

field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["it"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["'"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
          {
          "type": "word",
          "token": ["s"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}


print "text:", d['text']
print "tokens:", d['simple_tokens_original_case']
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results

# %%
#Ashley (702)

field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "punctuation",
          "token": ["("],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "shape",
          "shapes": ["ddd"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

print "text:", d['text']
print "tokens:", d['simple_tokens_original_case']
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results

# %%
#Jessica 7135975313

field_rules = {
  "rules": [
      {
      "identifier": "name_rule_05",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": [],
          "capitalization": ["title"],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "shape",
          "shapes": ["dddddddddd"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# []
# []

# %%
def text_rule(rule, text, answer):
    answer_lst = []
    results = c.extract_using_custom_spacy(d, config, field_rules=rule)
    for i in range(len(results)):
        answer_lst.append(results[i]['value'])      
    if answer_lst == answer:
        return True
    else:
        return False
