# %% [markdown]
# # Custom Spacy Rules

# %%
sampe_rules = {
  "rules": [
      {
      "identifier": "an indentifier",
      "description": "a description",
      "is_active": "true/false",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["tOWN", "job"],
          "capitalization": ["title", "upper", "mixed"],
          "part_of_speech": ["noun", "pronoun"],
          "length": [],
          "prefix": "ssss",
          "suffix": "",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": ["lower", "upper", "mixed"],
          "part_of_speech": [],
          "length": [5, 7],
          "prefix": "SA",
          "suffix": "WF",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "EEW",
          "suffix": "RHI",
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true/false",
          "is_out_of_vocabulary": "true"
        },
        {
          "type": "number",
          "tokens": [],
          "length": [],
          "prefix": [],
          "suffix": [],
          "min":"",
          "max":"",
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        },
        {
          "type": "shape",
          "shapes": ["xxxx", "xxxxxx", "XXXXXdd.dddXXxxxxxxx"],
          "part_of_speech": [],
          "prefix": "ss",
          "suffix": "pp",
          "is_followed_by_space": "true/false",
          "is_required": "true",
          "is_in_output": "true"
        },
        {
          "type": "punctuation",
          "token": [",", "?"],
          "is_followed_by_space": "true/false",
          "is_required": "false",
          "is_in_output": "true"
        },
        {
          "type": "symbol",
          "token": [],
          "is_followed_by_space": "true/false",
          "is_required": "true/false",
          "is_in_output": "true/false"
        }
      ]
    }
  ]
}

# %%
import json
from etk.core import Core
c = Core()

# %%
t = []
# t.append(u"Hello guy's, it's Jessica here from the #@%%% Spa. I cant say the name on here,")
t.append(u"Hi Gentlemen, My name is Ashley . I am the one and")
# t.append(u"Name : Sara . I am the one and, Name: JILL")
# t.append(u"Ashley (702)628-9035 XOXO ")
# t.append(u"I'm Ashley I'm bored ")
# t.append(u"this is Ashley1 I'm bored This is Ashley2")


field_rules = {
  "rules": [
      {
      "identifier": "name_rule_01",
      "description": "a description",
      "is_active": "true",
      "polarity": [],
      "pattern": [
        {
          "type": "word",
          "token": ["my"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["name", "names"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": ["is"],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "false",
          "is_out_of_vocabulary": ""
        },
        {
          "type": "word",
          "token": [],
          "capitalization": [],
          "part_of_speech": [],
          "length": [],
          "prefix": "",
          "suffix": "",
          "is_followed_by_space": "",
          "is_required": "true",
          "is_in_output": "true",
          "is_out_of_vocabulary": ""
        }
      ]
    }
  ]
}

d = dict()
d['text'] = "\n ".join(t)
print d['text']

config = dict()
config['field_name'] = 'field01'

print "RESULTS"
results = c.extract_using_custom_spacy(d, config, field_rules=field_rules)
print results
# Out:
# Hi Gentlemen, My name is Ashley . I am the one and
# RESULTS
# [{'context': {'start': 3, 'end': 7, 'rule_id': 0}, 'value': 'Ashley'}]
